# %% [markdown]
# # GRU scaling
# After successfully optimizing a GRU based neural network to predict wildfire risk in one California geopsatial bin, the next step is scale the model to make predictions for all 410 geospatial bins. A parallel GRU architecture will be employed. Each of the 410 geospatial bins in California will get it's own input layer and GRU layer, these will then be concatenated via a merge layer. The model output will be a 410 member vector where each element represents the prediction for one of the original geospatial bins.
#
# ### Goal:
# Scale GRU neural network to make predictions for all 410 geospatial bins in California. Save trained model weights and optimized hyperparameters for deployment.
#
# ### Plan:
# 1. Prep data from one geospatial bin for input into GRU
# 2. Build parallel GRU model
# 3. Using hyperparameters from the single GRU model as a starting point, tune and evaluate the parallel GRU model.
# 4. Save trained model weights and hyperparameters for model deployment

# %% [markdown]
# # Notebook setup

# %%
import os
import sys
import logging
import tracemalloc
import tensorflow as tf

# Note: tf 2.1.0 give warning about model weight format when
# using class weights. This is the only way to silence without
# updating
tf.get_logger().setLevel(logging.ERROR)
tf.random.set_seed(42)

import numpy as np
np.random.seed(42)

import pandas as pd
import tensorflow as tf
import sklearn as sk
from pickle import dump

from tensorflow import keras
from tensorflow.python.keras.optimizers import Adam
from tensorflow.python.keras import backend as K
from tensorflow.python.client import device_lib

# Note: sklearn forces depreciation warnings
# This is the only way to silence them without updating
def warn(*args, **kwargs):
    pass

import warnings
warnings.warn = warn

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import seaborn as sns

import helper_functions.plotting_functions as plotting_functions
import helper_functions.data_functions as data_functions
import helper_functions.config as config

print(f"Python {sys.version}")
print()
print(f"Pandas {pd.__version__}")
print(f"Tensorflow {tf.__version__}")
print(f"Keras {keras.__version__}")
print(f"SciKit Learn {sk.__version__}")
print()

devices = device_lib.list_local_devices()

if 'GPU' in ('').join(str(devices)):
    print("tf accessable GPU found: "+devices[-2].physical_device_desc)
# Out:
# Python 3.7.7 (default, Mar 23 2020, 22:36:06)
# [GCC 7.3.0]
#
# Pandas 1.0.3
# Tensorflow 2.2.0
# Keras 2.3.0-tf
# SciKit Learn 0.23.1
#
# tf accessable GPU found: device: 0, name: GeForce GTX 1070, pci bus id: 0000:02:00.0, compute capability: 6.1

# %% [markdown]
# # 1. Data preparation

# %%
# read data and grab features of intrest
data_file = '/mnt/SSD/data/training_data/1992-2015_california_standard_scaled_mean_selective_box_cox.parquet'
raw_data = pd.read_parquet(data_file)

# raw_data.drop([
#     'lat',
#     'lon',
#     'total_fires',
#     'veg',
#     'January',
#     'February',
#     'March',
#     'April',
#     'May',
#     'June',
#     'July',
#     'August',
#     'Septermber',
#     'October',
#     'November',
#     'December'
    
# ], inplace=True, axis=1)

# make sure data is sorted by date
raw_data['date'] = pd.to_datetime(raw_data['date'])
raw_data = raw_data.set_index('date')
raw_data = raw_data.sort_index()
raw_data.reset_index(inplace=True)

raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3594060 entries, 0 to 3594059
# Data columns (total 13 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   date              datetime64[ns]
#  1   month             float32
#  2   apcp              float32
#  3   mean_air_2m       float32
#  4   mean_rhum_2m      float32
#  5   mean_dpt_2m       float32
#  6   mean_pres_sfc     float32
#  7   mean_uwnd_10m     float32
#  8   mean_vwnd_10m     float32
#  9   mean_cloud_cover  float32
#  10  ignition          int32
#  11  raw_lat           float32
#  12  raw_lon           float32
# dtypes: datetime64[ns](1), float32(11), int32(1)
# memory usage: 191.9 MB

# %%
class_0_weight = ()
class_1_weight = ()
bins = raw_data.groupby(['raw_lat', 'raw_lon'])

for name, spatial_bin in bins:
    fires = spatial_bin['ignition'].sum()
    
    if fires == 0:
        class_0_weight = class_0_weight + (1,)
        class_1_weight = class_1_weight + (1,)
    
    else:
        observations = len(spatial_bin)
        class_0_weight = class_0_weight + (((1 / (observations - fires))*(observations)/2.0),)
        class_1_weight = class_1_weight + (((1 / fires)*(observations)/2.0),)

# %% [markdown]
# ### Split data into training, validation and testing sets
# Note: since temporal order matters here, we cannot simply randomly sample the data - we need to preserve the order. One possible improvement could be to break the data into many smaller ordered chunks and then sample those randomly...

# %%
# Split data up into training, testing and validation sets
testing_data = raw_data.tail(int(len(raw_data) * 0.1))
leftover_data = raw_data.head(int(len(raw_data) * 0.9))
validation_data = raw_data.tail(int(len(leftover_data) * 0.5))
training_data = raw_data.head(int(len(leftover_data) * 0.5))

# %% [markdown]
# Let's compare the distributions of each weather variable across the train, validation and test sets just to be sure that our samples are matched to a first approximation.

# %%
# plot split data distributions
features = [
    'apcp',
#     'crain',
#     'veg',
    'mean_air_2m',       
    'mean_rhum_2m', 
    'mean_dpt_2m', 
    'mean_pres_sfc', 
    'mean_uwnd_10m', 
    'mean_vwnd_10m', 
#     'mean_vis', 
    'mean_cloud_cover',
#     'range_air_2m',
#     'range_rhum_2m', 
#     'range_dpt_2m',
#     'range_pres_sfc',
#     'range_uwnd_10m',
#     'range_vwnd_10m',
#     'range_vis',
#     'range_cloud_cover'
]

left = config.left
right = config.right
bottom = config.bottom
top = config.top
wspace = config.wspace
hspace = config.hspace
fig_rows = 2
fig_cols = 4
plot_height = 7
plot_width = config.plot_width

plot_locations = [
    (0,0),(0,1),(0,2),(0,3),
    (1,0),(1,1),(1,2),(1,3)
]

xlabels = features
ylabels = ['Density'] * len(features)

# Make density plots
fig, ax = plt.subplots(fig_rows, fig_cols, figsize=(plot_width, plot_height))
fig.subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace)

for i in range(len(features)):
    ax[plot_locations[i]] = plotting_functions.three_sample_density_plot(
        ax,
        plot_locations[i], 
        training_data, 
        validation_data, 
        testing_data, 
        features[i], 
        features[i], 
        features[i], 
        ylabels[i]
    )
    
plt.show()

# %% [markdown]
# ### Format data for parallel GRU
# This part is a bit tricky - we need to form our data into samples, each sample containing 5 days of past history. Then we need a sequence of samples which spans the data set for each geospatial bin. Therefore, our input data will be a 410 member list of numpy arrays. The labels will be formated such that the first dimension is time and each time step contains a 410 member vector, one element for each of the 410 bins we are making predictions for.

# %%
num_fires = raw_data['ignition'].sum()
total_observations = len(raw_data)

print("Fires observed: {}".format(num_fires))
print("Total observations: {}".format(total_observations))
print()
print("Training data: {} observations".format(len(training_data)))
print("Validation data: {} observations".format(len(validation_data)))
print("Testing data: {} observations".format(len(testing_data)))
# Out:
# Fires observed: 124176
# Total observations: 3594060
#
# Training data: 1617327 observations
# Validation data: 1617327 observations
# Testing data: 359406 observations

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1617327 entries, 0 to 1617326
# Data columns (total 13 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   date              1617327 non-null  datetime64[ns]
#  1   month             1617327 non-null  float32
#  2   apcp              1617327 non-null  float32
#  3   mean_air_2m       1617327 non-null  float32
#  4   mean_rhum_2m      1617327 non-null  float32
#  5   mean_dpt_2m       1617327 non-null  float32
#  6   mean_pres_sfc     1617327 non-null  float32
#  7   mean_uwnd_10m     1617327 non-null  float32
#  8   mean_vwnd_10m     1617327 non-null  float32
#  9   mean_cloud_cover  1617327 non-null  float32
#  10  ignition          1617327 non-null  int32
#  11  raw_lat           1617327 non-null  float32
#  12  raw_lon           1617327 non-null  float32
# dtypes: datetime64[ns](1), float32(11), int32(1)
# memory usage: 86.4 MB

# %%
# Split data into 410 member lists, one element for each geospatial bin (and network input)
# each element of the list contains samples with a duration of past_history

past_history = 8
future_target = 1
step = 1

x_training, y_training, training_lats, training_lons, training_dates = data_functions.format_features_labels_for_LSTM(
    training_data,        # incomming_data
    past_history,         # size of past history time chunk
    future_target,        # number of future timepoints to predict from each history time chunk
    step,                 # number of timepoints to move the history time chunk as we slide over the data
)

x_validation, y_validation, validation_lats, validation_lons, validation_dates = data_functions.format_features_labels_for_LSTM(
    validation_data,      # incomming_data
    past_history,         # size of past history time chunk
    future_target,        # number of future timepoints to predict from each history time chunk
    step,                 # number of timepoints to move the history time chunk as we slide over the data
)

x_testing, y_testing, testing_lats, testing_lons, testing_dates = data_functions.format_features_labels_for_LSTM(
    testing_data,         # incomming_data
    past_history,         # size of past history time chunk
    future_target,        # number of future timepoints to predict from each history time chunk
    step,                 # number of timepoints to move the history time chunk as we slide over the data
)

# %%
print("x_training is {}, length: {}, member shape: {}.".format(type(x_training), len(x_training), x_training[0].shape))
print("y_training is {}, length: {}, member shape: {}.".format(type(y_training), len(y_training), y_training[0].shape))
print()
print("x_validation is {}, length: {}, member shape: {}.".format(type(x_validation), len(x_validation), x_validation[0].shape))
print("y_validation is {}, length: {}, member shape: {}.".format(type(y_validation), len(y_validation), y_validation[0].shape))
print()
print("x_testing is {}, length: {}, member shape: {}.".format(type(x_testing), len(x_testing), x_testing[0].shape))
print("y_testing is {}, length: {}, member shape: {}.".format(type(y_testing), len(y_testing), y_testing[0].shape))
# Out:
# x_training is <class 'list'>, length: 410, member shape: (3936, 8, 9).
# y_training is <class 'list'>, length: 410, member shape: (3936,).
#
# x_validation is <class 'list'>, length: 410, member shape: (3936, 8, 9).
# y_validation is <class 'list'>, length: 410, member shape: (3936,).
#
# x_testing is <class 'list'>, length: 410, member shape: (867, 8, 9).
# y_testing is <class 'list'>, length: 410, member shape: (867,).

# %%
x_training, y_training = data_functions.trim_and_reshape_for_LSTM(x_training, y_training)
x_validation, y_validation = data_functions.trim_and_reshape_for_LSTM(x_validation, y_validation)
x_testing, y_testing = data_functions.trim_and_reshape_for_LSTM(x_testing, y_testing)

# %%
print("x_training is {}, length: {}, member shape: {}.".format(type(x_training), len(x_training), x_training[0].shape))
print("y_training is {}, length: {}, member shape: {}.".format(type(y_training), len(y_training), y_training[0].shape))
print()
print("x_validation is {}, length: {}, member shape: {}.".format(type(x_validation), len(x_validation), x_validation[0].shape))
print("y_validation is {}, length: {}, member shape: {}.".format(type(y_validation), len(y_validation), y_validation[0].shape))
print()
print("x_testing is {}, length: {}, member shape: {}.".format(type(x_testing), len(x_testing), x_testing[0].shape))
print("y_testing is {}, length: {}, member shape: {}.".format(type(y_testing), len(y_testing), y_testing[0].shape))
# Out:
# x_training is <class 'list'>, length: 410, member shape: (3935, 8, 9).
# y_training is <class 'list'>, length: 3935, member shape: (410,).
#
# x_validation is <class 'list'>, length: 410, member shape: (3935, 8, 9).
# y_validation is <class 'list'>, length: 3935, member shape: (410,).
#
# x_testing is <class 'list'>, length: 410, member shape: (867, 8, 9).
# y_testing is <class 'list'>, length: 867, member shape: (410,).

# %%
# Trim each sample again to be a multiple of the batch size so we
# can do minibatch gradient descent - Note: this is required for statefull LSTMs

BATCH_SIZE = 4 * past_history

for i in range(len(x_training)):
    start_index = (x_training[i].shape[0] - (x_training[i].shape[0] % BATCH_SIZE))
    end_index = x_training[i].shape[0]

    x_training[i] = np.delete(x_training[i], range(start_index, end_index), axis=0)

y_training = np.delete(y_training, range(start_index, end_index), axis=0)

for i in range(len(x_validation)):
    start_index = (x_validation[i].shape[0] - (x_validation[i].shape[0] % BATCH_SIZE))
    end_index = x_validation[i].shape[0]

    x_validation[i] = np.delete(x_validation[i], range(start_index, end_index), axis=0)

y_validation = np.delete(y_validation, range(start_index, end_index), axis=0)

for i in range(len(x_testing)):
    start_index = (x_testing[i].shape[0] - (x_testing[i].shape[0] % BATCH_SIZE))
    end_index = x_testing[i].shape[0]

    x_testing[i] = np.delete(x_testing[i], range(start_index, end_index), axis=0)

y_testing = np.delete(y_testing, range(start_index, end_index), axis=0)

# %%
print("x_training is {}, length: {}, member shape: {}.".format(type(x_training), len(x_training), x_training[0].shape))
print("y_training is {}, length: {}, member shape: {}.".format(type(y_training), len(y_training), y_training[0].shape))
print()
print("x_validation is {}, length: {}, member shape: {}.".format(type(x_validation), len(x_validation), x_validation[0].shape))
print("y_validation is {}, length: {}, member shape: {}.".format(type(y_validation), len(y_validation), y_validation[0].shape))
print()
print("x_testing is {}, length: {}, member shape: {}.".format(type(x_testing), len(x_testing), x_testing[0].shape))
print("y_testing is {}, length: {}, member shape: {}.".format(type(y_testing), len(y_testing), y_testing[0].shape))
# Out:
# x_training is <class 'list'>, length: 410, member shape: (3904, 8, 9).
# y_training is <class 'numpy.ndarray'>, length: 3904, member shape: (410,).
#
# x_validation is <class 'list'>, length: 410, member shape: (3904, 8, 9).
# y_validation is <class 'numpy.ndarray'>, length: 3904, member shape: (410,).
#
# x_testing is <class 'list'>, length: 410, member shape: (864, 8, 9).
# y_testing is <class 'numpy.ndarray'>, length: 864, member shape: (410,).

# %% [markdown]
# # 2. Build parallel GRU model
# The general model architecture is as follows - 410 input layers, one for each geospatial bin. Each input feeds into it's own GRU layer. The GRU layers are then concatenated and make there way through a number of fully connected layers and finally to a 410 member sigmoid activated output.
#
# The loss function used is weighted binary cross-entropy. As this is a multilabel classification, not a multiclass classification softmax and categorical cross-entropy are not good choices because we can have more than one positive output amount the 410 for each time step.

# %%
# hyperparameters (adapted from single LSTM Cassandra model)
learning_rate = 0.01
parallel_gru_units = 8
# hidden_units = 100
# hidden_l2_lambda = 0.1
variational_dropout = 0.3

raw_output_bias = np.log([num_fires/(total_observations - num_fires)])[0]
output_bias = tf.keras.initializers.Constant(raw_output_bias)

metrics = [
    keras.metrics.TruePositives(name='true_positives'),
    keras.metrics.FalsePositives(name='false_positives'),
    keras.metrics.TrueNegatives(name='true_negatives'),
    keras.metrics.FalseNegatives(name='false_negatives'), 
    keras.metrics.AUC(name='AUC'),
    data_functions.matthews_correlation,
    data_functions.f1
]

# %%
inputs = []
GRUs = []
fully_connected_layers = []

# make list of inputs, one for each geospatial bin
for i in range(len(x_training)):
    inputs.append(
        keras.Input(
            batch_shape=(
                BATCH_SIZE,
                x_training[0].shape[1],
                x_training[0].shape[2]
            )
        )
    )
    
# make list of GRU layers, one for each geospatial bin
for i in range(len(x_training)):
    GRUs.append(keras.layers.GRU(
        parallel_gru_units,
        dropout=variational_dropout,
        stateful = False
    )(inputs[i]))
    
# merge GRU layers with concat layer
merged = keras.layers.concatenate(GRUs)

# dense = keras.layers.Dense(
#     hidden_units,
#     bias_initializer=keras.initializers.VarianceScaling(
#         scale=1.0,
#         mode='fan_in', 
#         distribution='normal', 
#         seed=42
#     ),
#     kernel_regularizer=keras.regularizers.l2(hidden_l2_lambda),
#     activation = 'relu'
# )(merged)

# output layer
output = keras.layers.Dense(
    len(x_training),
    activation = 'sigmoid',
    bias_initializer = output_bias
)(merged)

# compile model
model = keras.Model(inputs=inputs, outputs=output)

model.compile(
    optimizer=tf.keras.optimizers.Adam(lr = learning_rate),
    loss = data_functions.weighted_bce(class_0_weight, class_1_weight),
    metrics = metrics
)

#print(model.summary())

# %% [markdown]
# # 2. Train and evaluate parallel GRU model
# The general model architecture is as follows - 410 input layers, one for each geospatial bin. Each input feeds into it's own GRU layer. The GRU layers are then concatenated and make their way through a number of fully connected layers and finally to a 410 member sigmoid activated output.
#
# The loss function used is weighted binary cross-entropy. As this is a multilabel classification, not a multiclass classification softmax and categorical cross-entropy are not good choices because we can have more than one positive output among the 410 for each time step.

# %%
# %%time
tracemalloc.start()

STEPS_PER_EPOCH = (x_training[0].shape[0] * 1.0) // BATCH_SIZE
VALIDATION_STEPS = (x_validation[0].shape[0] * 1.0) // BATCH_SIZE

history = model.fit(
    x_training, 
    y_training,
    batch_size = BATCH_SIZE, 
    epochs = 25,
    steps_per_epoch = STEPS_PER_EPOCH,
    validation_steps = VALIDATION_STEPS,
    validation_data = (x_validation, y_validation)
)

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f'Peak memory: {np.round((peak / 10**6), 1)} MB')
# Out:
# Epoch 1/25
# 122/122 [==============================] - 381s 3s/step - loss: 1.9379 - true_positives: 34771.0000 - false_positives: 520035.0000 - true_negatives: 1023697.0000 - false_negatives: 22137.0000 - AUC: 0.6873 - matthews_correlation: 0.1043 - f1: 0.0864 - val_loss: 2.3628 - val_true_positives: 34854.0000 - val_false_positives: 621841.0000 - val_true_negatives: 922617.0000 - val_false_negatives: 21328.0000 - val_AUC: 0.6421 - val_matthews_correlation: 0.0436 - val_f1: 0.0532
# Epoch 2/25
# 122/122 [==============================] - 160s 1s/step - loss: 0.9515 - true_positives: 39367.0000 - false_positives: 483352.0000 - true_negatives: 1060380.0000 - false_negatives: 17541.0000 - AUC: 0.7499 - matthews_correlation: 0.1482 - f1: 0.1026 - val_loss: 1.9226 - val_true_positives: 37347.0000 - val_false_positives: 583387.0000 - val_true_negatives: 961071.0000 - val_false_negatives: 18835.0000 - val_AUC: 0.6770 - val_matthews_correlation: 0.0524 - val_f1: 0.0551
# Epoch 3/25
# 122/122 [==============================] - 159s 1s/step - loss: 0.6625 - true_positives: 41782.0000 - false_positives: 447536.0000 - true_negatives: 1096196.0000 - false_negatives: 15126.0000 - AUC: 0.7887 - matthews_correlation: 0.1772 - f1: 0.1116 - val_loss: 1.8687 - val_true_positives: 37010.0000 - val_false_positives: 569221.0000 - val_true_negatives: 975237.0000 - val_false_negatives: 19172.0000 - val_AUC: 0.6842 - val_matthews_correlation: 0.0553 - val_f1: 0.0550
# Epoch 4/25
# 122/122 [==============================] - 160s 1s/step - loss: 0.5482 - true_positives: 42863.0000 - false_positives: 411770.0000 - true_negatives: 1131962.0000 - false_negatives: 14045.0000 - AUC: 0.8148 - matthews_correlation: 0.1981 - f1: 0.1188 - val_loss: 1.7799 - val_true_positives: 34127.0000 - val_false_positives: 498228.0000 - val_true_negatives: 1046230.0000 - val_false_negatives: 22055.0000 - val_AUC: 0.6959 - val_matthews_correlation: 0.0621 - val_f1: 0.0537
# Epoch 5/25
# 122/122 [==============================] - 160s 1s/step - loss: 0.4999 - true_positives: 43828.0000 - false_positives: 390659.0000 - true_negatives: 1153073.0000 - false_negatives: 13080.0000 - AUC: 0.8307 - matthews_correlation: 0.2141 - f1: 0.1258 - val_loss: 1.7446 - val_true_positives: 32479.0000 - val_false_positives: 462341.0000 - val_true_negatives: 1082117.0000 - val_false_negatives: 23703.0000 - val_AUC: 0.7032 - val_matthews_correlation: 0.0633 - val_f1: 0.0533
# Epoch 6/25
# 122/122 [==============================] - 161s 1s/step - loss: 0.4585 - true_positives: 44588.0000 - false_positives: 366821.0000 - true_negatives: 1176911.0000 - false_negatives: 12320.0000 - AUC: 0.8475 - matthews_correlation: 0.2300 - f1: 0.1310 - val_loss: 1.7222 - val_true_positives: 32770.0000 - val_false_positives: 461955.0000 - val_true_negatives: 1082503.0000 - val_false_negatives: 23412.0000 - val_AUC: 0.7058 - val_matthews_correlation: 0.0655 - val_f1: 0.0537
# Epoch 7/25
# 122/122 [==============================] - 159s 1s/step - loss: 0.4309 - true_positives: 44839.0000 - false_positives: 348903.0000 - true_negatives: 1194829.0000 - false_negatives: 12069.0000 - AUC: 0.8581 - matthews_correlation: 0.2405 - f1: 0.1364 - val_loss: 1.7219 - val_true_positives: 34501.0000 - val_false_positives: 457670.0000 - val_true_negatives: 1086788.0000 - val_false_negatives: 21681.0000 - val_AUC: 0.7203 - val_matthews_correlation: 0.0774 - val_f1: 0.0544
# Epoch 8/25
# 122/122 [==============================] - 160s 1s/step - loss: 0.4225 - true_positives: 45210.0000 - false_positives: 336483.0000 - true_negatives: 1207249.0000 - false_negatives: 11698.0000 - AUC: 0.8647 - matthews_correlation: 0.2495 - f1: 0.1411 - val_loss: 1.7796 - val_true_positives: 36010.0000 - val_false_positives: 493144.0000 - val_true_negatives: 1051314.0000 - val_false_negatives: 20172.0000 - val_AUC: 0.7135 - val_matthews_correlation: 0.0773 - val_f1: 0.0547
# Epoch 9/25
# 122/122 [==============================] - 160s 1s/step - loss: 0.4060 - true_positives: 45582.0000 - false_positives: 325937.0000 - true_negatives: 1217795.0000 - false_negatives: 11326.0000 - AUC: 0.8715 - matthews_correlation: 0.2579 - f1: 0.1448 - val_loss: 1.7651 - val_true_positives: 31652.0000 - val_false_positives: 396070.0000 - val_true_negatives: 1148388.0000 - val_false_negatives: 24530.0000 - val_AUC: 0.7276 - val_matthews_correlation: 0.0757 - val_f1: 0.0523
# Epoch 10/25
# 122/122 [==============================] - 161s 1s/step - loss: 0.3894 - true_positives: 46030.0000 - false_positives: 312527.0000 - true_negatives: 1231205.0000 - false_negatives: 10878.0000 - AUC: 0.8797 - matthews_correlation: 0.2685 - f1: 0.1493 - val_loss: 1.8285 - val_true_positives: 30614.0000 - val_false_positives: 386891.0000 - val_true_negatives: 1157567.0000 - val_false_negatives: 25568.0000 - val_AUC: 0.7227 - val_matthews_correlation: 0.0683 - val_f1: 0.0514
# Epoch 11/25
# 122/122 [==============================] - 160s 1s/step - loss: 0.3811 - true_positives: 46099.0000 - false_positives: 302320.0000 - true_negatives: 1241412.0000 - false_negatives: 10809.0000 - AUC: 0.8844 - matthews_correlation: 0.2750 - f1: 0.1531 - val_loss: 1.7792 - val_true_positives: 29552.0000 - val_false_positives: 372405.0000 - val_true_negatives: 1172053.0000 - val_false_negatives: 26630.0000 - val_AUC: 0.7241 - val_matthews_correlation: 0.0752 - val_f1: 0.0518
# Epoch 12/25
# 122/122 [==============================] - 161s 1s/step - loss: 0.3678 - true_positives: 46246.0000 - false_positives: 290723.0000 - true_negatives: 1253009.0000 - false_negatives: 10662.0000 - AUC: 0.8904 - matthews_correlation: 0.2826 - f1: 0.1569 - val_loss: 1.8184 - val_true_positives: 28490.0000 - val_false_positives: 351021.0000 - val_true_negatives: 1193437.0000 - val_false_negatives: 27692.0000 - val_AUC: 0.7251 - val_matthews_correlation: 0.0802 - val_f1: 0.0512
# Epoch 13/25
# 122/122 [==============================] - 160s 1s/step - loss: 0.3600 - true_positives: 46585.0000 - false_positives: 282939.0000 - true_negatives: 1260793.0000 - false_negatives: 10323.0000 - AUC: 0.8948 - matthews_correlation: 0.2906 - f1: 0.1608 - val_loss: 1.8546 - val_true_positives: 30364.0000 - val_false_positives: 370888.0000 - val_true_negatives: 1173570.0000 - val_false_negatives: 25818.0000 - val_AUC: 0.7292 - val_matthews_correlation: 0.0813 - val_f1: 0.0518
# Epoch 14/25
# 122/122 [==============================] - 160s 1s/step - loss: 0.3523 - true_positives: 46710.0000 - false_positives: 274318.0000 - true_negatives: 1269414.0000 - false_negatives: 10198.0000 - AUC: 0.8991 - matthews_correlation: 0.2969 - f1: 0.1659 - val_loss: 1.8556 - val_true_positives: 29497.0000 - val_false_positives: 351039.0000 - val_true_negatives: 1193419.0000 - val_false_negatives: 26685.0000 - val_AUC: 0.7311 - val_matthews_correlation: 0.0814 - val_f1: 0.0515
# Epoch 15/25
# 122/122 [==============================] - 160s 1s/step - loss: 0.3455 - true_positives: 46708.0000 - false_positives: 266669.0000 - true_negatives: 1277063.0000 - false_negatives: 10200.0000 - AUC: 0.9025 - matthews_correlation: 0.3018 - f1: 0.1681 - val_loss: 1.8797 - val_true_positives: 29256.0000 - val_false_positives: 350291.0000 - val_true_negatives: 1194167.0000 - val_false_negatives: 26926.0000 - val_AUC: 0.7303 - val_matthews_correlation: 0.0765 - val_f1: 0.0516
# Epoch 16/25
# 122/122 [==============================] - 161s 1s/step - loss: 0.3355 - true_positives: 46980.0000 - false_positives: 257436.0000 - true_negatives: 1286296.0000 - false_negatives: 9928.0000 - AUC: 0.9069 - matthews_correlation: 0.3105 - f1: 0.1717 - val_loss: 1.8353 - val_true_positives: 30016.0000 - val_false_positives: 358287.0000 - val_true_negatives: 1186171.0000 - val_false_negatives: 26166.0000 - val_AUC: 0.7316 - val_matthews_correlation: 0.0859 - val_f1: 0.0523
# Epoch 17/25
# 122/122 [==============================] - 161s 1s/step - loss: 0.3327 - true_positives: 47019.0000 - false_positives: 252436.0000 - true_negatives: 1291296.0000 - false_negatives: 9889.0000 - AUC: 0.9090 - matthews_correlation: 0.3140 - f1: 0.1746 - val_loss: 1.9106 - val_true_positives: 28218.0000 - val_false_positives: 322450.0000 - val_true_negatives: 1222008.0000 - val_false_negatives: 27964.0000 - val_AUC: 0.7347 - val_matthews_correlation: 0.0864 - val_f1: 0.0512
# Epoch 18/25
# 122/122 [==============================] - 162s 1s/step - loss: 0.3265 - true_positives: 47199.0000 - false_positives: 247665.0000 - true_negatives: 1296067.0000 - false_negatives: 9709.0000 - AUC: 0.9117 - matthews_correlation: 0.3189 - f1: 0.1767 - val_loss: 1.9471 - val_true_positives: 27358.0000 - val_false_positives: 315694.0000 - val_true_negatives: 1228764.0000 - val_false_negatives: 28824.0000 - val_AUC: 0.7319 - val_matthews_correlation: 0.0802 - val_f1: 0.0510
# Epoch 19/25
# 122/122 [==============================] - 161s 1s/step - loss: 0.3229 - true_positives: 47336.0000 - false_positives: 243200.0000 - true_negatives: 1300532.0000 - false_negatives: 9572.0000 - AUC: 0.9140 - matthews_correlation: 0.3233 - f1: 0.1790 - val_loss: 1.9532 - val_true_positives: 26766.0000 - val_false_positives: 308320.0000 - val_true_negatives: 1236138.0000 - val_false_negatives: 29416.0000 - val_AUC: 0.7304 - val_matthews_correlation: 0.0809 - val_f1: 0.0506
# Epoch 20/25
# 122/122 [==============================] - 161s 1s/step - loss: 0.3177 - true_positives: 47473.0000 - false_positives: 236780.0000 - true_negatives: 1306952.0000 - false_negatives: 9435.0000 - AUC: 0.9166 - matthews_correlation: 0.3295 - f1: 0.1825 - val_loss: 1.9900 - val_true_positives: 23930.0000 - val_false_positives: 277760.0000 - val_true_negatives: 1266698.0000 - val_false_negatives: 32252.0000 - val_AUC: 0.7258 - val_matthews_correlation: 0.0745 - val_f1: 0.0481
# Epoch 21/25
# 122/122 [==============================] - 162s 1s/step - loss: 0.3165 - true_positives: 47623.0000 - false_positives: 234596.0000 - true_negatives: 1309136.0000 - false_negatives: 9285.0000 - AUC: 0.9178 - matthews_correlation: 0.3321 - f1: 0.1849 - val_loss: 2.0253 - val_true_positives: 25738.0000 - val_false_positives: 298354.0000 - val_true_negatives: 1246104.0000 - val_false_negatives: 30444.0000 - val_AUC: 0.7287 - val_matthews_correlation: 0.0816 - val_f1: 0.0501
# Epoch 22/25
# 122/122 [==============================] - 163s 1s/step - loss: 0.3145 - true_positives: 47553.0000 - false_positives: 230451.0000 - true_negatives: 1313281.0000 - false_negatives: 9355.0000 - AUC: 0.9194 - matthews_correlation: 0.3349 - f1: 0.1860 - val_loss: 2.0553 - val_true_positives: 28971.0000 - val_false_positives: 323116.0000 - val_true_negatives: 1221342.0000 - val_false_negatives: 27211.0000 - val_AUC: 0.7360 - val_matthews_correlation: 0.0883 - val_f1: 0.0517
# Epoch 23/25
# 122/122 [==============================] - 162s 1s/step - loss: 0.3149 - true_positives: 47656.0000 - false_positives: 229112.0000 - true_negatives: 1314620.0000 - false_negatives: 9252.0000 - AUC: 0.9201 - matthews_correlation: 0.3365 - f1: 0.1876 - val_loss: 2.0784 - val_true_positives: 26061.0000 - val_false_positives: 296610.0000 - val_true_negatives: 1247848.0000 - val_false_negatives: 30121.0000 - val_AUC: 0.7299 - val_matthews_correlation: 0.0807 - val_f1: 0.0498
# Epoch 24/25
# 122/122 [==============================] - 162s 1s/step - loss: 0.3129 - true_positives: 47668.0000 - false_positives: 226344.0000 - true_negatives: 1317388.0000 - false_negatives: 9240.0000 - AUC: 0.9211 - matthews_correlation: 0.3388 - f1: 0.1882 - val_loss: 2.1547 - val_true_positives: 26323.0000 - val_false_positives: 287876.0000 - val_true_negatives: 1256582.0000 - val_false_negatives: 29859.0000 - val_AUC: 0.7361 - val_matthews_correlation: 0.0867 - val_f1: 0.0496
# Epoch 25/25
# 122/122 [==============================] - 161s 1s/step - loss: 0.3094 - true_positives: 47770.0000 - false_positives: 222704.0000 - true_negatives: 1321028.0000 - false_negatives: 9138.0000 - AUC: 0.9227 - matthews_correlation: 0.3429 - f1: 0.1907 - val_loss: 2.1467 - val_true_positives: 25524.0000 - val_false_positives: 281641.0000 - val_true_negatives: 1262817.0000 - val_false_negatives: 30658.0000 - val_AUC: 0.7321 - val_matthews_correlation: 0.0831 - val_f1: 0.0496
# Peak memory: 2467.5 MB
# CPU times: user 1h 41min 14s, sys: 11min 6s, total: 1h 52min 21s
# Wall time: 1h 25min 26s

# %%
# plot learning curves
metric_names =  [
    'loss', 
    'matthews_correlation', 
    'true_positives', 
    'false_positives', 
    'false_negatives', 
    'true_negatives'
]

filename = '../project_info/figures/parallel_LSTM_learning_curves.png'
print(f"Total observations: {len(training_data)}")

plotting_functions.plot_metrics('Parallel GRU', history, metric_names, filename)
# Out:
# Total observations: 1617327

# %%
# %%time
tracemalloc.start()

training_predictions = model.predict(x_training, batch_size=BATCH_SIZE)
training_ignition_risk_predictions = training_predictions.flatten()
training_true_fires = y_training.flatten()

testing_predictions = model.predict(x_testing, batch_size=BATCH_SIZE)
testing_ignition_risk_predictions = testing_predictions.flatten()
testing_true_fires = y_testing.flatten()

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f'Peak memory: {np.round((peak / 10**6), 1)} MB')
# Out:
# Peak memory: 503.1 MB
# CPU times: user 5min 9s, sys: 11.2 s, total: 5min 20s
# Wall time: 4min 49s

# %%
sns.kdeplot(training_ignition_risk_predictions, cumulative=False, bw=0.01)
plt.xlim(-0.1, 1)
plt.show()

# %%
# %%time
tracemalloc.start()

training_results = model.evaluate(
    x_training,
    y_training,
    batch_size=BATCH_SIZE
)

testing_results = model.evaluate(
    x_testing,
    y_testing, 
    batch_size=BATCH_SIZE
)

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f'Peak memory: {np.round((peak / 10**6), 1)} MB')
# Out:
# 122/122 [==============================] - 45s 366ms/step - loss: 0.2535 - true_positives: 53531.0000 - false_positives: 265354.0000 - true_negatives: 1278378.0000 - false_negatives: 3377.0000 - AUC: 0.9412 - matthews_correlation: 0.3272 - f1: 0.1337
# 27/27 [==============================] - 10s 363ms/step - loss: 1.8610 - true_positives: 5296.0000 - false_positives: 68570.0000 - true_negatives: 273915.0000 - false_negatives: 6459.0000 - AUC: 0.7126 - matthews_correlation: 0.0766 - f1: 0.0469
# Peak memory: 472.4 MB
# CPU times: user 1min 16s, sys: 9.21 s, total: 1min 25s
# Wall time: 1min 1s

# %%
filename ='../project_info/figures/parallel_GRU_confusion_matricies.png'  
plotting_functions.plot_cm(training_true_fires, training_ignition_risk_predictions, testing_true_fires, testing_ignition_risk_predictions, filename)
# Out:
# Training data prediction results
# No fire (True Negatives):  1278378
# False alarms (False Positives):  265354
# Fires missed (False Negatives):  3377
# Fires detected (True Positives):  53531
# Total fires:  56908
#
# Test data prediction results
# No fire (True Negatives):  273915
# False alarms (False Positives):  68570
# Fires missed (False Negatives):  6459
# Fires detected (True Positives):  5296
# Total fires:  11755

# %%
trimmed_training_dates = training_dates[:training_predictions.shape[0]]

formatted_predictions = pd.DataFrame(columns=['date', 'lat', 'lon', 'prediction'])

for prediction, date in zip(training_predictions, trimmed_training_dates):
    df = pd.DataFrame(list(zip(training_lats, training_lons, prediction)), 
               columns =['lat', 'lon', 'prediction'])
    
    df['date'] = date
    
    formatted_predictions = formatted_predictions.append(df)
    
formatted_predictions.head()
# Out:
#         date        lat         lon    prediction
# 0 1992-01-01  32.683891 -117.180901  1.198636e-09
# 1 1992-01-01  32.721279 -116.851196  4.145146e-01
# 2 1992-01-01  32.757439 -116.521004  1.158308e-04
# 3 1992-01-01  32.792389 -116.190498  9.958618e-07
# 4 1992-01-01  32.826099 -115.859596  1.022728e-02

# %% [markdown]
# Worried that trimming the dates list is deforming the data. Implicit assumption is that the difference in lengths between the full date list and the first dimension of the predictions array is all at the end. May not be true. Need a better way to flatten and reassemble the geospatial time bins from LSTM input format.

# %%
formatted_predictions.tail()
# Out:
#           date        lat         lon  prediction
# 405 2002-09-08  41.859089 -122.052498    0.420974
# 406 2002-09-08  41.898472 -123.652901    0.001266
# 407 2002-09-08  41.916180 -121.671700    0.755300
# 408 2002-09-08  41.961609 -123.273499    0.736407
# 409 2002-09-08  41.971821 -121.290199    0.039405

# %%
states_shapefile = '../training_data_pipeline/data/spatial_data/cb_2018_us_state_500k.shp'
california = data_functions.get_california_polygon(states_shapefile)
multipoly = california.loc[16, 'geometry']
california_land_mass = multipoly[-1]

# %%
from descartes import PolygonPatch

left  = 0.125  # the left side of the subplots of the figure
right = 0.65   # the right side of the subplots of the figure
bottom = 0.1   # the bottom of the subplots of the figure
top = 0.9      # the top of the subplots of the figure
wspace = 0.2   # the amount of width reserved for blank space between subplots
hspace = 0.3   # the amount of height reserved for white space between subplots

fig_rows = 8
fig_cols = 2
plot_height = 65
plot_width = 30

plot_locations = [
    (0,0),(0,1),
    (1,0),(1,1),
    (2,0),(2,1),
    (3,0),(3,1),
    (4,0),(4,1),
    (5,0),(5,1),
    (6,0),(6,1),
    (7,0),(7,1)
]

date_list = [
    '1999-01-01',
    '1999-02-01',
    '1999-03-01',
    '1999-04-01',
    '1999-05-01',
    '1999-06-01',
    '1999-07-01',
    '1999-08-01',
    '1999-09-01',
    '1999-10-01',
    '1999-11-01',
    '1999-12-01',
    '2000-01-01',
    '2000-02-01',
    '2000-03-01',
    '2000-04-01'
    
]

# date_list = [
#     '1999-01-01',
#     '1999-01-02',
#     '1999-01-03',
#     '1999-01-04',
#     '1999-01-05',
#     '1999-01-06',
#     '1999-01-07',
#     '1999-01-08',
#     '1999-01-09',
#     '1999-01-10',
#     '1999-01-11',
#     '1999-01-12',
#     '2000-01-13',
#     '2000-01-14',
#     '2000-01-15',
#     '2000-01-16'  
# ]

num_contour_levels = 10

# formatted_predictions['lat'] = formatted_predictions['lat'].astype('float32')
# formatted_predictions['lon'] = formatted_predictions['lon'].astype('float32')

# prediction_data_by_day = formatted_predictions.groupby('date')

fig, ax = plt.subplots(fig_rows, fig_cols, figsize=(plot_width, plot_height))
fig.subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace)

i = 0

while i < 16:
    date = str(date_list[i])
    predictions = formatted_predictions[formatted_predictions['date'] == date]
    predictions.drop('date', axis=1, inplace=True)

    xi, yi, zi = data_functions.regularize_grid(predictions, 'prediction', 0.1)

    ax[plot_locations[i]].add_patch(PolygonPatch(california_land_mass, fc='none', ec='black', lw='2', zorder=2))
    ax[plot_locations[i]].contourf(xi, yi, zi, num_contour_levels, cmap='viridis')
    ax[plot_locations[i]].set_title(date, fontsize=18)
    ax[plot_locations[i]].set_aspect('equal', adjustable='box')
    
    i += 1

# %% [markdown]
# # 4. Save model for deployment

# %%
# %%time

# save trained weights
tracemalloc.start()

model.save_weights('./trained_model_weights/parallel_GRU')

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f'Peak memory: {np.round((peak / 10**6), 1)} MB')

# %%
# %%time

# save model note: need to use .h5 format to avoid apparent memory leak in TF 
# bug report: https://github.com/tensorflow/tensorflow/issues/32234
tracemalloc.start()

model.save('./trained_models/parallel_GRU.h5')

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f'Peak memory: {np.round((peak / 10**6), 1)} MB')

# %% [markdown]
# Mock up some data to match what the live prediction data will look like to ensure the model works as expected after round tripping the weights.

# %%
# past_history = 5
# future_target = 1
# step = 1
# BATCH_SIZE = 1

# x_training, y_training = data_functions.format_features_labels_for_LSTM(
#     training_data,        # incomming_data
#     past_history,         # size of past history time chunk
#     future_target,        # number of future timepoints to predict from each history time chunk
#     step,                 # number of timepoints to move the history time chunk as we slide over the data
# )

# x_training, y_training = data_functions.trim_and_reshape_for_LSTM(x_training, y_training)

# for i in range(len(x_training)):
#     start_index = (x_training[i].shape[0] - (x_training[i].shape[0] % BATCH_SIZE))
#     end_index = x_training[i].shape[0]

#     x_training[i] = np.delete(x_training[i], range(start_index, end_index), axis=0)

# %%
# mock_data = []

# for spatial_bin in x_training:
#     bin_slice = spatial_bin[0:7,:,]
#     mock_data.append(bin_slice)
    
# mock_labels = y_training[0:7]
    
# print("x_training is {}, length: {}, member shape: {}.".format(type(x_training), len(x_training), x_training[0].shape))
# print("y_training is {}, length: {}, member shape: {}.".format(type(y_training), len(y_training), y_training[0].shape))
# print("mock_data is {}, length: {}, member shape: {}.".format(type(mock_data), len(mock_data), mock_data[0].shape))
# print("mock_labels are {}, length: {}, member shape: {}.".format(type(mock_labels), len(mock_labels), mock_labels[0].shape))

# %%
# inputs = []
# LSTMs = []

# for i in range(len(mock_data)):
#     inputs.append(
#         keras.Input(
#             batch_shape=(
#                 BATCH_SIZE,
#                 mock_data[0].shape[1],
#                 mock_data[0].shape[2]
#             )
#         )
#     )
    
# for i in range(len(mock_data)):
#     LSTMs.append(keras.layers.LSTM(
#         lstm_units,
#         dropout = variational_dropout,
#         stateful = True
#     )(inputs[i]))
    
# merged = keras.layers.concatenate(LSTMs)

# hidden1 = keras.layers.Dense(
#     hidden_units,
#     kernel_regularizer=keras.regularizers.l1(hidden_l1_lambda),
#     bias_initializer=tf.keras.initializers.he_normal(),
#     activation = 'relu'
# )(merged)

# hidden2 = keras.layers.Dense(
#     hidden_units,
#     kernel_regularizer=keras.regularizers.l1(hidden_l1_lambda),
#     bias_initializer=tf.keras.initializers.he_normal(),
#     activation = 'relu'
# )(hidden1)

# output = keras.layers.Dense(
#     410,
#     activation = 'sigmoid',
#     bias_initializer = output_bias
# )(hidden2)

# production_model = keras.Model(inputs=inputs, outputs=output)

# production_model.load_weights('./trained_model_weights/parallel_LSTM_weights.tf')
# production_model.summary()

# %%
# mock_predictions = production_model.predict(mock_data)
# flat_mock_predictions = mock_predictions.flatten()

# %%
# sns.kdeplot(flat_mock_predictions, cumulative=False, bw=0.01)
# plt.xlim(-0.1, 1)
# plt.show()
