# %% [markdown]
# # Notebook setup

# %%
import os
import sys
import logging
import tracemalloc
import time

import pandas as pd
import tensorflow as tf
import sklearn as sk
import skopt as so
import numpy as np

from pickle import dump

# Note: tf 2.1.0 give warning about model weight format when
# using class weights. This is the only way to silence without
# updating
tf.get_logger().setLevel(logging.ERROR)

tf.random.set_seed(42)
np.random.seed(42)

from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.python.keras.optimizers import Adam
from tensorflow.python.keras import backend as K
from tensorflow.python.client import device_lib

# Note: sklearn forces depreciation warnings
# This is the only way to silence them without updating
def warn(*args, **kwargs):
    pass

import warnings
warnings.warn = warn

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.metrics import confusion_matrix

from skopt.space import Real, Categorical, Integer
from skopt.utils import use_named_args
from skopt.plots import plot_objective, plot_evaluations
from skopt import gp_minimize

import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import seaborn as sns

import helper_functions.plotting_functions as plotting_functions
import helper_functions.data_functions as data_functions
import helper_functions.config as config

print(f"Python {sys.version}")
print()
print(f"Pandas {pd.__version__}")
print(f"Tensorflow {tf.__version__}")
print(f"Keras {keras.__version__}")
print(f"SciKit Learn {sk.__version__}")
print(f"SciKit Optimize {so.__version__}")
print()

devices = device_lib.list_local_devices()

if 'GPU' in ('').join(str(devices)):
    print("tf accessable GPU found: "+devices[-2].physical_device_desc)
# Out:
# /home/siderealyear/anaconda3/envs/wildfire_production/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Python 3.7.7 (default, Mar 23 2020, 22:36:06)
# [GCC 7.3.0]
#
# Pandas 1.0.3
# Tensorflow 2.2.0
# Keras 2.3.0-tf
# SciKit Learn 0.23.1
# SciKit Optimize 0.4
#
# tf accessable GPU found: device: 0, name: GeForce GTX 1070, pci bus id: 0000:02:00.0, compute capability: 6.1

# %% [markdown]
# # 1. Data preparation

# %%
# read data
data_file = '/mnt/SSD/data/training_data/1992-2015_california_min-1_max1_scaled_mean.parquet'
raw_data = pd.read_parquet(data_file)

# make sure data is sorted by date
raw_data['date'] = pd.to_datetime(raw_data['date'])
raw_data = raw_data.set_index('date')
raw_data = raw_data.sort_index()
raw_data.reset_index(inplace=True)
raw_data.drop(['month', 'total_fires'], inplace=True, axis=1)

raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3594060 entries, 0 to 3594059
# Data columns (total 14 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   date              datetime64[ns]
#  1   lat               float32
#  2   lon               float32
#  3   apcp              float32
#  4   mean_air_2m       float32
#  5   mean_rhum_2m      float32
#  6   mean_dpt_2m       float32
#  7   mean_pres_sfc     float32
#  8   mean_uwnd_10m     float32
#  9   mean_vwnd_10m     float32
#  10  mean_cloud_cover  float32
#  11  ignition          int32
#  12  raw_lat           float32
#  13  raw_lon           float32
# dtypes: datetime64[ns](1), float32(12), int32(1)
# memory usage: 205.7 MB

# %%
geospatial_bins = raw_data[['raw_lat', 'raw_lon']]
geospatial_bins.head(n=20)
# Out:
#       raw_lat     raw_lon
# 0   32.683891 -117.180901
# 1   38.961529 -123.557899
# 2   35.232731 -117.260803
# 3   38.575668 -120.454903
# 4   37.182751 -121.959801
# 5   38.978210 -121.676399
# 6   40.208530 -123.153397
# 7   36.557789 -120.359802
# 8   35.209370 -119.710999
# 9   41.740639 -122.811699
# 10  37.202690 -117.603600
# 11  35.616890 -120.860298
# 12  35.907410 -118.793404
# 13  38.524029 -122.682503
# 14  34.567230 -115.421799
# 15  33.756569 -117.699799
# 16  37.217979 -119.782097
# 17  36.047581 -119.889297
# 18  33.239319 -117.272003
# 19  41.552299 -123.944199

# %% [markdown]
# ### Randomly chosen geospatial bins
# 1. Grass Valley Wilderness Area, Barstow: 35.232731, -117.260803
# 2. Lexington Hills: 37.182751, -121.959801
# 3. Cantua Creek: 36.557789, -120.359802
# 4. Klamath: 41.552299, -123.944199

# %%
barstow = raw_data[(raw_data['raw_lat'] == 35.232731) & (raw_data['raw_lon'] == -117.260803)]
lexington = raw_data[(raw_data['raw_lat'] == 37.182751) & (raw_data['raw_lon'] == -121.959801)]
cantua = raw_data[(raw_data['raw_lat'] == 36.557789) & (raw_data['raw_lon'] == -120.359802)]
klamath = raw_data[(raw_data['raw_lat'] == 41.552299) & (raw_data['raw_lon'] == -123.944199)]

print(f'Num time points: {len(klamath)}')
print()

data = pd.concat([barstow, lexington, klamath])
data.info()
# Out:
# Num time points: 8766
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26298 entries, 2 to 3593914
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              26298 non-null  datetime64[ns]
#  1   lat               26298 non-null  float32
#  2   lon               26298 non-null  float32
#  3   apcp              26298 non-null  float32
#  4   mean_air_2m       26298 non-null  float32
#  5   mean_rhum_2m      26298 non-null  float32
#  6   mean_dpt_2m       26298 non-null  float32
#  7   mean_pres_sfc     26298 non-null  float32
#  8   mean_uwnd_10m     26298 non-null  float32
#  9   mean_vwnd_10m     26298 non-null  float32
#  10  mean_cloud_cover  26298 non-null  float32
#  11  ignition          26298 non-null  int32
#  12  raw_lat           26298 non-null  float32
#  13  raw_lon           26298 non-null  float32
# dtypes: datetime64[ns](1), float32(12), int32(1)
# memory usage: 1.7 MB

# %%
class_0_weight = ()
class_1_weight = ()
bins = data.groupby(['raw_lat', 'raw_lon'])

for name, spatial_bin in bins:
    fires = spatial_bin['ignition'].sum()
    
    if fires == 0:
        class_0_weight = class_0_weight + (1,)
        class_1_weight = class_1_weight + (1,)
    
    else:
        observations = len(spatial_bin)
        class_0_weight = class_0_weight + (((1 / (observations - fires))*(observations)/2.0),)
        class_1_weight = class_1_weight + (((1 / fires)*(observations)/2.0),)
        
print(f'Class 0 weights: {class_0_weight}')
print(f'Class 1 weights: {class_1_weight}')
# Out:
# Class 0 weights: (0.5006282124500285, 0.5665718717683558, 0.5122122239102489)
# Class 1 weights: (398.45454545454544, 4.255339805825242, 20.971291866028707)

# %%
num_fires = data['ignition'].sum()
total_observations = len(data)
raw_output_bias = np.log([num_fires/(total_observations - num_fires)])[0]
output_bias = tf.keras.initializers.Constant(raw_output_bias)

print(f'Output bias: {raw_output_bias}')
# Out:
# Output bias: -2.9976504327098947

# %% [markdown]
# ### Split data into training, validation and testing sets
# Note: since temporal order matters here, we cannot simply randomly sample the data - we need to preserve the order. One possible improvement could be to break the data into many smaller ordered chunks and then sample those randomly...

# %%
# make sure data is STILL sorted by date
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data = data.sort_index()
data.reset_index(inplace=True)

# Split data up into training, testing and validation sets
testing_data = data.tail(int(len(data) * 0.2))
leftover_data = data.head(int(len(data) * 0.8))
validation_data = data.tail(int(len(leftover_data) * 0.5))
training_data = data.head(int(len(leftover_data) * 0.5))

# %% [markdown]
# Let's compare the distributions of each weather variable across the train, validation and test sets just to be sure that our samples are matched to a first approximation.

# %%
# plot split data distributions
features = [
    'lat',
    'lon',
#     'month',
    'apcp',
#     'crain',
#     'veg',
    'mean_air_2m',       
    'mean_rhum_2m', 
    'mean_dpt_2m', 
    'mean_pres_sfc', 
    'mean_uwnd_10m', 
    'mean_vwnd_10m', 
#     'mean_vis', 
    'mean_cloud_cover',
#     'total_fires',
    'ignition'
#     'range_air_2m',
#     'range_rhum_2m', 
#     'range_dpt_2m',
#     'range_pres_sfc',
#     'range_uwnd_10m',
#     'range_vwnd_10m',
#     'range_vis',
#     'range_cloud_cover'
]

left = config.left
right = config.right
bottom = config.bottom
top = config.top
wspace = config.wspace
hspace = config.hspace
fig_rows = 4
fig_cols = 4
plot_height = 10
plot_width = config.plot_width

plot_locations = [
    (0,0),(0,1),(0,2),(0,3),
    (1,0),(1,1),(1,2),(1,3),
    (2,0),(2,1),(2,2),(2,3),
    (3,0),(3,1),(3,2),(3,3),
]

xlabels = features
ylabels = ['Density'] * len(features)

# Make density plots
fig, ax = plt.subplots(fig_rows, fig_cols, figsize=(plot_width, plot_height))
fig.subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace)

for i in range(len(features)):
    ax[plot_locations[i]] = plotting_functions.three_sample_density_plot(
        ax,
        plot_locations[i], 
        training_data, 
        validation_data, 
        testing_data, 
        features[i], 
        features[i], 
        features[i], 
        ylabels[i]
    )
    
plt.show()

# %% [markdown]
# # 2. Set up gaussian process optimization

# %%
# metrics to track
metrics = [
    keras.metrics.TruePositives(name='true_positives'),
    keras.metrics.FalsePositives(name='false_positives'),
    keras.metrics.TrueNegatives(name='true_negatives'),
    keras.metrics.FalseNegatives(name='false_negatives'), 
    keras.metrics.AUC(name='auc'),
    data_functions.matthews_correlation,
    data_functions.f1
]

#metrics = config.metrics

# dimensions to include in GPM search space
dim_learning_rate = Real(
    low=0.0001,
    high=0.1, 
    name='learning_rate'
)

dim_past_history = Integer(
    low=1,
    high=5, 
    name='past_history'
)

dim_batch_size = Integer(
    low=32,
    high=128,
    name='batch_size'
)

dim_rnn_type = Integer(
    low=0,
    high=1,
    name='rnn_type'
)

dim_statefullness = Integer(
    low=0,
    high=1,
    name='statefullness'
)

dim_rnn_units = Integer(
    low=1, 
    high=10,
    name='rnn_units'
)

dim_rnn_dropout = Real(
    low=0.0, 
    high=0.5,
    name='rnn_dropout'
)

dim_fc_unit_factor = Integer(
    low=2, 
    high=10,
    name='fc_unit_factor'
)

dim_fc_layers = Integer(
    low=0, 
    high=5,
    name='fc_layers'
)

dim_fc_l2_reg = Real(
    low=0.0, 
    high=0.3,
    name='fc_l2_reg'
)

dimensions = [
    dim_learning_rate,
    dim_past_history,
    dim_batch_size,
    dim_rnn_type,
    dim_statefullness,
    dim_rnn_units,
    dim_rnn_dropout,
    dim_fc_unit_factor,
    dim_fc_layers,
    dim_fc_l2_reg
    
]

default_parameters = [0.01, 5, 64, 1, 1, 10, 0.1, 3, 3, 0.0]

# Use early stopping
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'val_loss', 
    patience = 5,
    mode = 'min',
    restore_best_weights = True
)

future_target = 1
step = 1
EPOCHS = 20

# also set initial value for output bias based on fire frequency
# raw_output_bias = np.log([num_fires/(total_observations - num_fires)])
# output_bias = tf.keras.initializers.Constant(raw_output_bias)

path_best_model = './trained_models/small_scale_parallel_RNN_optimization.keras'
best_val_loss = 1000

run_num = 1
total_elapsed = 0.0

# %%
def make_model(
    num_bins,
    input_shape,
    learning_rate,
    rnn_type,
    statefullness,
    rnn_units,
    rnn_dropout,
    fc_unit_factor,
    fc_layers,
    fc_l2_reg,
    class_0_weight,
    class_1_weight,
    output_bias
):    
    
    if statefullness == 0:
        statefullness = False
        
    elif statefullness == 1:
        statefullness = True
    
    inputs = []
    RNNs = []

    # make list of inputs, one for each geospatial bin
    for i in range(num_bins):
        inputs.append(
            keras.Input(
                batch_shape=input_shape
            )
        )
    
    if rnn_type == 0:
        # make list of LSTM layers, one for each geospatial bin
        for i in range(num_bins):
            RNNs.append(keras.layers.LSTM(
                rnn_units,
                dropout=rnn_dropout,
                stateful=statefullness
            )(inputs[i]))
            
    elif rnn_type == 1:
        # make list of GRU layers, one for each geospatial bin
        for i in range(num_bins):
            RNNs.append(keras.layers.GRU(
                rnn_units,
                dropout=rnn_dropout,
                stateful=statefullness
            )(inputs[i]))

    # merge LSTM layers with concat layer
    merged = keras.layers.concatenate(RNNs)
    
    if fc_layers == 0:
        # output layer
        output = keras.layers.Dense(
            num_bins,
            activation='sigmoid',
            bias_initializer=output_bias
        )(merged) 
        
    
    elif fc_layers > 0:
        i = 0
        io_layers = []
        io_layers.append(merged)
        
        while i <= fc_layers:
            # add fully connected layer
            io_layers.append(keras.layers.Dense(
                (num_bins * fc_unit_factor),
                kernel_regularizer=regularizers.l2(fc_l2_reg),
                bias_initializer=keras.initializers.VarianceScaling(
                    scale=1.0,
                    mode='fan_in', 
                    distribution='normal', 
                    seed=42
                ),
                activation = 'relu'
            )(io_layers[i]))

            i += 1

        # output layer
        output = keras.layers.Dense(
            num_bins,
            activation='sigmoid',
            bias_initializer=output_bias
        )(io_layers[-1])        

    # compile model
    model = keras.Model(inputs=inputs, outputs=output)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr = learning_rate),
        loss = data_functions.weighted_bce(class_0_weight, class_1_weight),
        metrics = metrics
    )

    return model

# %%
@use_named_args(dimensions=dimensions)
def fitness(
    learning_rate,
    past_history,
    batch_size,
    rnn_type,
    statefullness,
    rnn_units,
    rnn_dropout,
    fc_unit_factor,
    fc_layers,
    fc_l2_reg
):
    
    # create data sets
    x_training, y_training, training_lats, training_lons, training_dates = data_functions.format_features_labels_for_LSTM(
        training_data,        # incomming_data
        past_history,         # size of past history time chunk
        future_target,        # number of future timepoints to predict from each history time chunk
        step,                 # number of timepoints to move the history time chunk as we slide over the data
    )

    x_validation, y_validation, validation_lats, validation_lons, validation_dates = data_functions.format_features_labels_for_LSTM(
        validation_data,      # incomming_data
        past_history,         # size of past history time chunk
        future_target,        # number of future timepoints to predict from each history time chunk
        step,                 # number of timepoints to move the history time chunk as we slide over the data
    )
    
    x_training, y_training = data_functions.trim_and_reshape_for_LSTM(x_training, y_training)
    x_validation, y_validation = data_functions.trim_and_reshape_for_LSTM(x_validation, y_validation)
    
    # trim datasets so they are a whole number factor of the batch size
    for i in range(len(x_training)):
        start_index = (x_training[i].shape[0] - (x_training[i].shape[0] % batch_size))
        end_index = x_training[i].shape[0]

        x_training[i] = np.delete(x_training[i], range(start_index, end_index), axis=0)

    y_training = np.delete(y_training, range(start_index, end_index), axis=0)

    for i in range(len(x_validation)):
        start_index = (x_validation[i].shape[0] - (x_validation[i].shape[0] % batch_size))
        end_index = x_validation[i].shape[0]

        x_validation[i] = np.delete(x_validation[i], range(start_index, end_index), axis=0)

    y_validation = np.delete(y_validation, range(start_index, end_index), axis=0)
    
#     print()
#     print("x_training is {}, length: {}, member shape: {}.".format(type(x_training), len(x_training), x_training[0].shape))
#     print("y_training is {}, length: {}, member shape: {}.".format(type(y_training), len(y_training), y_training[0].shape))
#     print()
#     print("x_validation is {}, length: {}, member shape: {}.".format(type(x_validation), len(x_validation), x_validation[0].shape))
#     print("y_validation is {}, length: {}, member shape: {}.".format(type(y_validation), len(y_validation), y_validation[0].shape))
#     print()

    input_dim = x_training[0].shape[-2:]
    input_shape = (batch_size, input_dim[0], input_dim[1])
    num_bins = len(x_training)
#     print(f'Input shape: {input_shape}')
#     print(f'Num bins: {num_bins}')
#     print()
    
    # steps from batch size
    steps_per_epoch = int(len(x_training[0]) // batch_size)
    validation_steps = int(len(x_validation[0]) // batch_size)
    
#     print(f'Batch size: {batch_size}')
#     print(f'Training steps: {steps_per_epoch}')
#     print(f'Validation steps: {validation_steps}')
#     print(f'Fully connected layers: {fc_layers}')
#     print()
    
    # Create the neural network with these hyper-parameters.
    
#     fc_unit_factor = 0
#     fc_layers = 0
#     fc_l2_reg = 0
    
    model = make_model(
        num_bins=num_bins,
        input_shape=input_shape,
        learning_rate=learning_rate,
        rnn_type=rnn_type,
        statefullness=statefullness,
        rnn_units=rnn_units,
        rnn_dropout=rnn_dropout,
        fc_unit_factor=fc_unit_factor,
        fc_layers=fc_layers,
        fc_l2_reg=fc_l2_reg,
        class_0_weight=class_0_weight,
        class_1_weight=class_1_weight,
        output_bias=output_bias
    )
    
#     model.summary()
    
    global run_num
    global total_elapsed
    
    # Use Keras to train the model
    start = time.time()
    
    history = model.fit(
        x_training,
        y_training,
        epochs=EPOCHS,
        batch_size=batch_size,
        steps_per_epoch=steps_per_epoch,
        callbacks=[early_stopping_callback],
        validation_data=(x_validation, y_validation),
        validation_steps=validation_steps,
        verbose=0
    )
    
    end = time.time()
    elapsed = (end - start) / 60
    total_elapsed = total_elapsed + elapsed

    # Get validation loss for training run
    val_loss = history.history['val_loss'][-1]

    # Save the model if it improves on the best-found performance.
    # We use the global keyword so we update the variable outside
    # of this function.
    global best_val_loss

    # If the validation loss of the saved model is improved ...
    if val_loss < best_val_loss:
        # Save the new model to harddisk.
        model.save(path_best_model)
        
        # Update the classification accuracy.
        best_val_loss = val_loss
        
    # Delete the Keras model with these hyper-parameters from memory.
    del model
    
    # Clear the Keras session, otherwise it will keep adding new
    # models to the same TensorFlow graph each time we create
    # a model with a different set of hyper-parameters.
    K.clear_session()
    
    if run_num % 10 == 0:
        print(f'Run {run_num}, {np.round(total_elapsed, 1)} min. elapsed in model.fit(), best validation loss so far: {np.round(best_val_loss, 2)}')
    
    run_num += 1
        
    # NOTE: Scikit-optimize does minimization so it tries to
    # find a set of hyper-parameters with the LOWEST fitness-value.
    # Because we are interested in the HIGHEST MCC, we need to 
    # negate this number so it can be minimized.
    return val_loss

# %%
# %%time

# do the optimization run
search_result = gp_minimize(
    func=fitness,
    dimensions=dimensions,
    acq_func='EI', # Expected Improvement.
    n_calls=200,
    x0=default_parameters
)
# Out:
# Run 10, 4.9 min. elapsed in model.fit(), best validation loss so far: 0.64
# Run 20, 8.1 min. elapsed in model.fit(), best validation loss so far: 0.62
# Run 30, 12.0 min. elapsed in model.fit(), best validation loss so far: 0.61
# Run 40, 15.1 min. elapsed in model.fit(), best validation loss so far: 0.61
# Run 50, 18.4 min. elapsed in model.fit(), best validation loss so far: 0.61
# Run 60, 22.8 min. elapsed in model.fit(), best validation loss so far: 0.59
# Run 70, 26.5 min. elapsed in model.fit(), best validation loss so far: 0.59
# Run 80, 29.7 min. elapsed in model.fit(), best validation loss so far: 0.59
# Run 90, 33.0 min. elapsed in model.fit(), best validation loss so far: 0.57
# Run 100, 35.6 min. elapsed in model.fit(), best validation loss so far: 0.57
# CPU times: user 1h 1min 41s, sys: 5min 1s, total: 1h 6min 43s
# Wall time: 40min 41s

# %%
from skopt.plots import plot_convergence
plot_convergence(search_result)

# %%
# extract and plot optimization results
dim_names = [
    'learning_rate',
    'past_history',
    'batch_size',
    'rnn_type',
    'statefullness',
    'rnn_units',
    'rnn_dropout',
    'fc_unit_factor',
    'fc_layers',
    'fc_l2_reg'
]

fig, ax = plot_objective(result=search_result, dimension_names=dim_names)
plt.savefig('../project_info/figures/small_scale_RNN_GPO.png', bbox_inches='tight')

# %%
# winning hyperparameters
space = search_result.space
winning_hyperparams = space.point_to_dict(search_result.x)
winning_hyperparams
# Out:
# {'learning_rate': 0.05360449885539629,
#  'past_history': 3,
#  'batch_size': 57,
#  'rnn_type': 1,
#  'statefullness': 0,
#  'rnn_units': 10,
#  'rnn_dropout': 0.08975669528435455,
#  'fc_unit_factor': 9,
#  'fc_layers': 0,
#  'fc_l2_reg': 0.2329674895898586}

# %%
# set up training run with winning values
# learning_rate = winning_hyperparams['learning_rate']
# past_history = winning_hyperparams['past_history']
# batch_size = winning_hyperparams['batch_size']
# rnn_type = winning_hyperparams['rnn_type']
# statefullness = winning_hyperparams['statefullness']
# rnn_units = winning_hyperparams['rnn_units']
# rnn_dropout = winning_hyperparams['rnn_dropout']
# fc_unit_factor = winning_hyperparams['fc_unit_factor']
# fc_layers = winning_hyperparams['fc_layers']
# fc_l2_reg = winning_hyperparams['fc_l2_reg']

# %%
learning_rate = 0.001
past_history = 5
batch_size = 32
rnn_type = 0 # 1 = GRU, 0 = LSTM
statefullness = 1
rnn_units = 10
rnn_dropout = 0.0
fc_unit_factor = 3
fc_layers = 0
fc_l2_reg = 0.3

step = 1
future_target = 1

# %%
# create data sets
x_training, y_training, training_lats, training_lons, training_dates = data_functions.format_features_labels_for_LSTM(
    training_data,        # incomming_data
    past_history,         # size of past history time chunk
    future_target,        # number of future timepoints to predict from each history time chunk
    step,                 # number of timepoints to move the history time chunk as we slide over the data
)

x_validation, y_validation, validation_lats, validation_lons, validation_dates = data_functions.format_features_labels_for_LSTM(
    validation_data,      # incomming_data
    past_history,         # size of past history time chunk
    future_target,        # number of future timepoints to predict from each history time chunk
    step,                 # number of timepoints to move the history time chunk as we slide over the data
)

x_testing, y_testing, testing_lats, testing_lons, testing_dates = data_functions.format_features_labels_for_LSTM(
    testing_data,         # incomming_data
    past_history,         # size of past history time chunk
    future_target,        # number of future timepoints to predict from each history time chunk
    step,                 # number of timepoints to move the history time chunk as we slide over the data
)

x_training, y_training = data_functions.trim_and_reshape_for_LSTM(x_training, y_training)
x_validation, y_validation = data_functions.trim_and_reshape_for_LSTM(x_validation, y_validation)
x_testing, y_testing = data_functions.trim_and_reshape_for_LSTM(x_testing, y_testing)

# trim datasets so they are a whole number factor of the batch size
for i in range(len(x_training)):
    start_index = (x_training[i].shape[0] - (x_training[i].shape[0] % batch_size))
    end_index = x_training[i].shape[0]

    x_training[i] = np.delete(x_training[i], range(start_index, end_index), axis=0)

y_training = np.delete(y_training, range(start_index, end_index), axis=0)

for i in range(len(x_validation)):
    start_index = (x_validation[i].shape[0] - (x_validation[i].shape[0] % batch_size))
    end_index = x_validation[i].shape[0]

    x_validation[i] = np.delete(x_validation[i], range(start_index, end_index), axis=0)

y_validation = np.delete(y_validation, range(start_index, end_index), axis=0)

for i in range(len(x_testing)):
    start_index = (x_testing[i].shape[0] - (x_testing[i].shape[0] % batch_size))
    end_index = x_testing[i].shape[0]

    x_testing[i] = np.delete(x_testing[i], range(start_index, end_index), axis=0)

y_testing = np.delete(y_testing, range(start_index, end_index), axis=0)

print()
print("x_training is {}, length: {}, member shape: {}.".format(type(x_training), len(x_training), x_training[0].shape))
print("y_training is {}, length: {}, member shape: {}.".format(type(y_training), len(y_training), y_training[0].shape))
print()
print("x_validation is {}, length: {}, member shape: {}.".format(type(x_validation), len(x_validation), x_validation[0].shape))
print("y_validation is {}, length: {}, member shape: {}.".format(type(y_validation), len(y_validation), y_validation[0].shape))
print()
print("x_testing is {}, length: {}, member shape: {}.".format(type(x_testing), len(x_testing), x_testing[0].shape))
print("y_testing is {}, length: {}, member shape: {}.".format(type(y_testing), len(y_testing), y_testing[0].shape))
print()

input_dim = x_training[0].shape[-2:]
input_shape = (batch_size, input_dim[0], input_dim[1])
num_bins = len(x_training)
print(f'Input shape: {input_shape}')
print(f'Num bins: {num_bins}')
print()

# steps from batch size
steps_per_epoch = int(len(x_training[0]) // batch_size)
validation_steps = int(len(x_validation[0]) // batch_size)
# Out:
# x_training is <class 'list'>, length: 3, member shape: (3488, 5, 10).
# y_training is <class 'numpy.ndarray'>, length: 3488, member shape: (3,).
#
# x_validation is <class 'list'>, length: 3, member shape: (3488, 5, 10).
# y_validation is <class 'numpy.ndarray'>, length: 3488, member shape: (3,).
#
# x_testing is <class 'list'>, length: 3, member shape: (1728, 5, 10).
# y_testing is <class 'numpy.ndarray'>, length: 1728, member shape: (3,).
#
# Input shape: (32, 5, 10)
# Num bins: 3

# %%
# fc_unit_factor = 0
# fc_layers = 0
# fc_l2_reg = 0

model = make_model(
    num_bins,
    input_shape,
    learning_rate,
    rnn_type,
    statefullness,
    rnn_units,
    rnn_dropout,
    fc_unit_factor,
    fc_layers,
    fc_l2_reg,
    class_0_weight,
    class_1_weight,
    output_bias
)

# %%
# %%time
tracemalloc.start()

history = model.fit(
    x_training,
    y_training,
    epochs=50,
    batch_size=batch_size,
    steps_per_epoch=steps_per_epoch,
    #callbacks=[early_stopping_callback],
    validation_data=(x_validation, y_validation),
    validation_steps=validation_steps,
    verbose=1
)
# Out:
# Epoch 1/50
# 109/109 [==============================] - 5s 44ms/step - loss: 1.7823 - true_positives: 296.0000 - false_positives: 4888.0000 - true_negatives: 9997.0000 - false_negatives: 467.0000 - auc: 0.5664 - matthews_correlation: 0.0000e+00 - f1: 0.0000e+00 - val_loss: 0.6908 - val_true_positives: 0.0000e+00 - val_false_positives: 0.0000e+00 - val_true_negatives: 9881.0000 - val_false_negatives: 583.0000 - val_auc: 0.7959 - val_matthews_correlation: 0.0000e+00 - val_f1: 0.0000e+00
# Epoch 2/50
# 109/109 [==============================] - 3s 25ms/step - loss: 1.0649 - true_positives: 193.0000 - false_positives: 1376.0000 - true_negatives: 8621.0000 - false_negatives: 274.0000 - auc: 0.7600 - matthews_correlation: 0.1282 - f1: 0.0449 - val_loss: 0.6220 - val_true_positives: 399.0000 - val_false_positives: 1858.0000 - val_true_negatives: 8023.0000 - val_false_negatives: 184.0000 - val_auc: 0.8354 - val_matthews_correlation: 0.1945 - val_f1: 0.0696
# Epoch 3/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.8051 - true_positives: 307.0000 - false_positives: 4143.0000 - true_negatives: 5854.0000 - false_negatives: 160.0000 - auc: 0.6223 - matthews_correlation: 0.1091 - f1: 0.1097 - val_loss: 0.6265 - val_true_positives: 441.0000 - val_false_positives: 5887.0000 - val_true_negatives: 3994.0000 - val_false_negatives: 142.0000 - val_auc: 0.5891 - val_matthews_correlation: -0.0309 - val_f1: 0.0775
# Epoch 4/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7206 - true_positives: 365.0000 - false_positives: 5235.0000 - true_negatives: 4762.0000 - false_negatives: 102.0000 - auc: 0.6561 - matthews_correlation: 0.1054 - f1: 0.1229 - val_loss: 0.6300 - val_true_positives: 424.0000 - val_false_positives: 5248.0000 - val_true_negatives: 4633.0000 - val_false_negatives: 159.0000 - val_auc: 0.5860 - val_matthews_correlation: -0.0175 - val_f1: 0.0798
# Epoch 5/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7143 - true_positives: 357.0000 - false_positives: 4815.0000 - true_negatives: 5182.0000 - false_negatives: 110.0000 - auc: 0.6572 - matthews_correlation: 0.1153 - f1: 0.1318 - val_loss: 0.6680 - val_true_positives: 448.0000 - val_false_positives: 6317.0000 - val_true_negatives: 3564.0000 - val_false_negatives: 135.0000 - val_auc: 0.5518 - val_matthews_correlation: -0.0398 - val_f1: 0.0803
# Epoch 6/50
# 109/109 [==============================] - 2s 21ms/step - loss: 0.6809 - true_positives: 366.0000 - false_positives: 5238.0000 - true_negatives: 4759.0000 - false_negatives: 101.0000 - auc: 0.6192 - matthews_correlation: 0.1050 - f1: 0.1303 - val_loss: 0.6374 - val_true_positives: 434.0000 - val_false_positives: 5625.0000 - val_true_negatives: 4256.0000 - val_false_negatives: 149.0000 - val_auc: 0.5944 - val_matthews_correlation: -0.0250 - val_f1: 0.0796
# Epoch 7/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6628 - true_positives: 366.0000 - false_positives: 4451.0000 - true_negatives: 5546.0000 - false_negatives: 101.0000 - auc: 0.6991 - matthews_correlation: 0.1338 - f1: 0.1306 - val_loss: 0.6631 - val_true_positives: 426.0000 - val_false_positives: 5598.0000 - val_true_negatives: 4283.0000 - val_false_negatives: 157.0000 - val_auc: 0.5685 - val_matthews_correlation: -0.0280 - val_f1: 0.0789
# Epoch 8/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6695 - true_positives: 367.0000 - false_positives: 4554.0000 - true_negatives: 5443.0000 - false_negatives: 100.0000 - auc: 0.6730 - matthews_correlation: 0.1312 - f1: 0.1301 - val_loss: 0.6593 - val_true_positives: 421.0000 - val_false_positives: 5536.0000 - val_true_negatives: 4345.0000 - val_false_negatives: 162.0000 - val_auc: 0.5607 - val_matthews_correlation: -0.0298 - val_f1: 0.0770
# Epoch 9/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6550 - true_positives: 358.0000 - false_positives: 4669.0000 - true_negatives: 5328.0000 - false_negatives: 109.0000 - auc: 0.6426 - matthews_correlation: 0.1189 - f1: 0.1290 - val_loss: 0.6300 - val_true_positives: 416.0000 - val_false_positives: 4798.0000 - val_true_negatives: 5083.0000 - val_false_negatives: 167.0000 - val_auc: 0.6169 - val_matthews_correlation: 0.0060 - val_f1: 0.0819
# Epoch 10/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6518 - true_positives: 368.0000 - false_positives: 4360.0000 - true_negatives: 5637.0000 - false_negatives: 99.0000 - auc: 0.6922 - matthews_correlation: 0.1436 - f1: 0.1314 - val_loss: 0.6530 - val_true_positives: 386.0000 - val_false_positives: 4727.0000 - val_true_negatives: 5154.0000 - val_false_negatives: 197.0000 - val_auc: 0.5802 - val_matthews_correlation: -0.0225 - val_f1: 0.0764
# Epoch 11/50
# 109/109 [==============================] - 2s 22ms/step - loss: 0.6470 - true_positives: 361.0000 - false_positives: 4282.0000 - true_negatives: 5715.0000 - false_negatives: 106.0000 - auc: 0.6719 - matthews_correlation: 0.1401 - f1: 0.1345 - val_loss: 0.6358 - val_true_positives: 426.0000 - val_false_positives: 5001.0000 - val_true_negatives: 4880.0000 - val_false_negatives: 157.0000 - val_auc: 0.6106 - val_matthews_correlation: 0.0049 - val_f1: 0.0825
# Epoch 12/50
# 109/109 [==============================] - 2s 21ms/step - loss: 0.6391 - true_positives: 377.0000 - false_positives: 4549.0000 - true_negatives: 5448.0000 - false_negatives: 90.0000 - auc: 0.6682 - matthews_correlation: 0.1414 - f1: 0.1330 - val_loss: 0.6320 - val_true_positives: 433.0000 - val_false_positives: 5052.0000 - val_true_negatives: 4829.0000 - val_false_negatives: 150.0000 - val_auc: 0.6069 - val_matthews_correlation: 0.0105 - val_f1: 0.0861
# Epoch 13/50
# 109/109 [==============================] - 2s 22ms/step - loss: 0.6319 - true_positives: 375.0000 - false_positives: 4330.0000 - true_negatives: 5667.0000 - false_negatives: 92.0000 - auc: 0.6814 - matthews_correlation: 0.1448 - f1: 0.1327 - val_loss: 0.6548 - val_true_positives: 446.0000 - val_false_positives: 5541.0000 - val_true_negatives: 4340.0000 - val_false_negatives: 137.0000 - val_auc: 0.5867 - val_matthews_correlation: -0.0083 - val_f1: 0.0822
# Epoch 14/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6489 - true_positives: 378.0000 - false_positives: 4433.0000 - true_negatives: 5564.0000 - false_negatives: 89.0000 - auc: 0.6695 - matthews_correlation: 0.1469 - f1: 0.1345 - val_loss: 0.6533 - val_true_positives: 415.0000 - val_false_positives: 5003.0000 - val_true_negatives: 4878.0000 - val_false_negatives: 168.0000 - val_auc: 0.5859 - val_matthews_correlation: -0.0118 - val_f1: 0.0786
# Epoch 15/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6370 - true_positives: 373.0000 - false_positives: 4500.0000 - true_negatives: 5497.0000 - false_negatives: 94.0000 - auc: 0.6599 - matthews_correlation: 0.1375 - f1: 0.1293 - val_loss: 0.6264 - val_true_positives: 402.0000 - val_false_positives: 4446.0000 - val_true_negatives: 5435.0000 - val_false_negatives: 181.0000 - val_auc: 0.6086 - val_matthews_correlation: 0.0074 - val_f1: 0.0792
# Epoch 16/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6218 - true_positives: 376.0000 - false_positives: 4147.0000 - true_negatives: 5850.0000 - false_negatives: 91.0000 - auc: 0.6976 - matthews_correlation: 0.1602 - f1: 0.1378 - val_loss: 0.6297 - val_true_positives: 410.0000 - val_false_positives: 4521.0000 - val_true_negatives: 5360.0000 - val_false_negatives: 173.0000 - val_auc: 0.6117 - val_matthews_correlation: 0.0104 - val_f1: 0.0800
# Epoch 17/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6220 - true_positives: 368.0000 - false_positives: 4115.0000 - true_negatives: 5882.0000 - false_negatives: 99.0000 - auc: 0.6917 - matthews_correlation: 0.1539 - f1: 0.1351 - val_loss: 0.6417 - val_true_positives: 381.0000 - val_false_positives: 4424.0000 - val_true_negatives: 5457.0000 - val_false_negatives: 202.0000 - val_auc: 0.5894 - val_matthews_correlation: -0.0144 - val_f1: 0.0762
# Epoch 18/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6356 - true_positives: 372.0000 - false_positives: 4225.0000 - true_negatives: 5772.0000 - false_negatives: 95.0000 - auc: 0.6871 - matthews_correlation: 0.1512 - f1: 0.1344 - val_loss: 0.6472 - val_true_positives: 418.0000 - val_false_positives: 4929.0000 - val_true_negatives: 4952.0000 - val_false_negatives: 165.0000 - val_auc: 0.5926 - val_matthews_correlation: -0.0048 - val_f1: 0.0802
# Epoch 19/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6238 - true_positives: 374.0000 - false_positives: 4353.0000 - true_negatives: 5644.0000 - false_negatives: 93.0000 - auc: 0.6708 - matthews_correlation: 0.1489 - f1: 0.1326 - val_loss: 0.6273 - val_true_positives: 402.0000 - val_false_positives: 4247.0000 - val_true_negatives: 5634.0000 - val_false_negatives: 181.0000 - val_auc: 0.6268 - val_matthews_correlation: 0.0145 - val_f1: 0.0799
# Epoch 20/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6214 - true_positives: 373.0000 - false_positives: 4166.0000 - true_negatives: 5831.0000 - false_negatives: 94.0000 - auc: 0.6869 - matthews_correlation: 0.1489 - f1: 0.1325 - val_loss: 0.6312 - val_true_positives: 427.0000 - val_false_positives: 4806.0000 - val_true_negatives: 5075.0000 - val_false_negatives: 156.0000 - val_auc: 0.6132 - val_matthews_correlation: 0.0126 - val_f1: 0.0816
# Epoch 21/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6102 - true_positives: 377.0000 - false_positives: 4007.0000 - true_negatives: 5990.0000 - false_negatives: 90.0000 - auc: 0.7117 - matthews_correlation: 0.1666 - f1: 0.1371 - val_loss: 0.6582 - val_true_positives: 466.0000 - val_false_positives: 5447.0000 - val_true_negatives: 4434.0000 - val_false_negatives: 117.0000 - val_auc: 0.6018 - val_matthews_correlation: 0.0226 - val_f1: 0.0895
# Epoch 22/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6055 - true_positives: 387.0000 - false_positives: 4282.0000 - true_negatives: 5715.0000 - false_negatives: 80.0000 - auc: 0.6855 - matthews_correlation: 0.1598 - f1: 0.1335 - val_loss: 0.6168 - val_true_positives: 415.0000 - val_false_positives: 4317.0000 - val_true_negatives: 5564.0000 - val_false_negatives: 168.0000 - val_auc: 0.6404 - val_matthews_correlation: 0.0310 - val_f1: 0.0811
# Epoch 23/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6192 - true_positives: 375.0000 - false_positives: 4105.0000 - true_negatives: 5892.0000 - false_negatives: 92.0000 - auc: 0.6907 - matthews_correlation: 0.1571 - f1: 0.1325 - val_loss: 0.6383 - val_true_positives: 415.0000 - val_false_positives: 4625.0000 - val_true_negatives: 5256.0000 - val_false_negatives: 168.0000 - val_auc: 0.6074 - val_matthews_correlation: 0.0091 - val_f1: 0.0805
# Epoch 24/50
# 109/109 [==============================] - 2s 20ms/step - loss: 0.6273 - true_positives: 388.0000 - false_positives: 4421.0000 - true_negatives: 5576.0000 - false_negatives: 79.0000 - auc: 0.6665 - matthews_correlation: 0.1553 - f1: 0.1355 - val_loss: 0.6192 - val_true_positives: 403.0000 - val_false_positives: 4349.0000 - val_true_negatives: 5532.0000 - val_false_negatives: 180.0000 - val_auc: 0.6205 - val_matthews_correlation: 0.0093 - val_f1: 0.0781
# Epoch 25/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6175 - true_positives: 385.0000 - false_positives: 4289.0000 - true_negatives: 5708.0000 - false_negatives: 82.0000 - auc: 0.6874 - matthews_correlation: 0.1619 - f1: 0.1367 - val_loss: 0.6252 - val_true_positives: 424.0000 - val_false_positives: 4747.0000 - val_true_negatives: 5134.0000 - val_false_negatives: 159.0000 - val_auc: 0.6135 - val_matthews_correlation: 0.0128 - val_f1: 0.0817
# Epoch 26/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6132 - true_positives: 379.0000 - false_positives: 4202.0000 - true_negatives: 5795.0000 - false_negatives: 88.0000 - auc: 0.6900 - matthews_correlation: 0.1556 - f1: 0.1331 - val_loss: 0.6194 - val_true_positives: 432.0000 - val_false_positives: 4670.0000 - val_true_negatives: 5211.0000 - val_false_negatives: 151.0000 - val_auc: 0.6256 - val_matthews_correlation: 0.0258 - val_f1: 0.0832
# Epoch 27/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6072 - true_positives: 382.0000 - false_positives: 4257.0000 - true_negatives: 5740.0000 - false_negatives: 85.0000 - auc: 0.6887 - matthews_correlation: 0.1557 - f1: 0.1361 - val_loss: 0.6250 - val_true_positives: 418.0000 - val_false_positives: 4470.0000 - val_true_negatives: 5411.0000 - val_false_negatives: 165.0000 - val_auc: 0.6273 - val_matthews_correlation: 0.0224 - val_f1: 0.0811
# Epoch 28/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6062 - true_positives: 383.0000 - false_positives: 4332.0000 - true_negatives: 5665.0000 - false_negatives: 84.0000 - auc: 0.6838 - matthews_correlation: 0.1505 - f1: 0.1317 - val_loss: 0.6326 - val_true_positives: 417.0000 - val_false_positives: 4509.0000 - val_true_negatives: 5372.0000 - val_false_negatives: 166.0000 - val_auc: 0.6173 - val_matthews_correlation: 0.0229 - val_f1: 0.0822
# Epoch 29/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6102 - true_positives: 387.0000 - false_positives: 4336.0000 - true_negatives: 5661.0000 - false_negatives: 80.0000 - auc: 0.6834 - matthews_correlation: 0.1577 - f1: 0.1352 - val_loss: 0.6350 - val_true_positives: 423.0000 - val_false_positives: 4851.0000 - val_true_negatives: 5030.0000 - val_false_negatives: 160.0000 - val_auc: 0.5970 - val_matthews_correlation: 0.0048 - val_f1: 0.0815
# Epoch 30/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5992 - true_positives: 384.0000 - false_positives: 4232.0000 - true_negatives: 5765.0000 - false_negatives: 83.0000 - auc: 0.6850 - matthews_correlation: 0.1617 - f1: 0.1370 - val_loss: 0.6243 - val_true_positives: 425.0000 - val_false_positives: 4705.0000 - val_true_negatives: 5176.0000 - val_false_negatives: 158.0000 - val_auc: 0.6163 - val_matthews_correlation: 0.0146 - val_f1: 0.0794
# Epoch 31/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6123 - true_positives: 381.0000 - false_positives: 4219.0000 - true_negatives: 5778.0000 - false_negatives: 86.0000 - auc: 0.6888 - matthews_correlation: 0.1594 - f1: 0.1331 - val_loss: 0.6347 - val_true_positives: 446.0000 - val_false_positives: 4961.0000 - val_true_negatives: 4920.0000 - val_false_negatives: 137.0000 - val_auc: 0.6123 - val_matthews_correlation: 0.0299 - val_f1: 0.0882
# Epoch 32/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6006 - true_positives: 381.0000 - false_positives: 4181.0000 - true_negatives: 5816.0000 - false_negatives: 86.0000 - auc: 0.6879 - matthews_correlation: 0.1608 - f1: 0.1377 - val_loss: 0.6239 - val_true_positives: 416.0000 - val_false_positives: 4681.0000 - val_true_negatives: 5200.0000 - val_false_negatives: 167.0000 - val_auc: 0.6140 - val_matthews_correlation: 0.0053 - val_f1: 0.0793
# Epoch 33/50
# 109/109 [==============================] - 3s 23ms/step - loss: 0.6044 - true_positives: 376.0000 - false_positives: 4226.0000 - true_negatives: 5771.0000 - false_negatives: 91.0000 - auc: 0.6897 - matthews_correlation: 0.1529 - f1: 0.1323 - val_loss: 0.6206 - val_true_positives: 421.0000 - val_false_positives: 4674.0000 - val_true_negatives: 5207.0000 - val_false_negatives: 162.0000 - val_auc: 0.6244 - val_matthews_correlation: 0.0099 - val_f1: 0.0790
# Epoch 34/50
# 109/109 [==============================] - 2s 22ms/step - loss: 0.5860 - true_positives: 378.0000 - false_positives: 4051.0000 - true_negatives: 5946.0000 - false_negatives: 89.0000 - auc: 0.7083 - matthews_correlation: 0.1605 - f1: 0.1349 - val_loss: 0.6524 - val_true_positives: 462.0000 - val_false_positives: 5319.0000 - val_true_negatives: 4562.0000 - val_false_negatives: 121.0000 - val_auc: 0.6100 - val_matthews_correlation: 0.0303 - val_f1: 0.0888
# Epoch 35/50
# 109/109 [==============================] - 2s 22ms/step - loss: 0.6185 - true_positives: 375.0000 - false_positives: 4274.0000 - true_negatives: 5723.0000 - false_negatives: 92.0000 - auc: 0.6899 - matthews_correlation: 0.1542 - f1: 0.1327 - val_loss: 0.6365 - val_true_positives: 428.0000 - val_false_positives: 4621.0000 - val_true_negatives: 5260.0000 - val_false_negatives: 155.0000 - val_auc: 0.6279 - val_matthews_correlation: 0.0228 - val_f1: 0.0812
# Epoch 36/50
# 109/109 [==============================] - 2s 23ms/step - loss: 0.6025 - true_positives: 379.0000 - false_positives: 4149.0000 - true_negatives: 5848.0000 - false_negatives: 88.0000 - auc: 0.6926 - matthews_correlation: 0.1563 - f1: 0.1327 - val_loss: 0.6200 - val_true_positives: 421.0000 - val_false_positives: 4282.0000 - val_true_negatives: 5599.0000 - val_false_negatives: 162.0000 - val_auc: 0.6583 - val_matthews_correlation: 0.0378 - val_f1: 0.0814
# Epoch 37/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.5899 - true_positives: 374.0000 - false_positives: 4040.0000 - true_negatives: 5957.0000 - false_negatives: 93.0000 - auc: 0.7026 - matthews_correlation: 0.1614 - f1: 0.1328 - val_loss: 0.6253 - val_true_positives: 420.0000 - val_false_positives: 4361.0000 - val_true_negatives: 5520.0000 - val_false_negatives: 163.0000 - val_auc: 0.6438 - val_matthews_correlation: 0.0312 - val_f1: 0.0806
# Epoch 38/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6079 - true_positives: 386.0000 - false_positives: 4162.0000 - true_negatives: 5835.0000 - false_negatives: 81.0000 - auc: 0.6977 - matthews_correlation: 0.1687 - f1: 0.1353 - val_loss: 0.6720 - val_true_positives: 447.0000 - val_false_positives: 5358.0000 - val_true_negatives: 4523.0000 - val_false_negatives: 136.0000 - val_auc: 0.5755 - val_matthews_correlation: 0.0039 - val_f1: 0.0855
# Epoch 39/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.5934 - true_positives: 371.0000 - false_positives: 4225.0000 - true_negatives: 5772.0000 - false_negatives: 96.0000 - auc: 0.6781 - matthews_correlation: 0.1445 - f1: 0.1330 - val_loss: 0.6308 - val_true_positives: 463.0000 - val_false_positives: 5232.0000 - val_true_negatives: 4649.0000 - val_false_negatives: 120.0000 - val_auc: 0.6289 - val_matthews_correlation: 0.0309 - val_f1: 0.0886
# Epoch 40/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5984 - true_positives: 384.0000 - false_positives: 4237.0000 - true_negatives: 5760.0000 - false_negatives: 83.0000 - auc: 0.6927 - matthews_correlation: 0.1571 - f1: 0.1328 - val_loss: 0.6280 - val_true_positives: 434.0000 - val_false_positives: 4812.0000 - val_true_negatives: 5069.0000 - val_false_negatives: 149.0000 - val_auc: 0.6192 - val_matthews_correlation: 0.0150 - val_f1: 0.0805
# Epoch 41/50
# 109/109 [==============================] - 3s 23ms/step - loss: 0.5794 - true_positives: 385.0000 - false_positives: 4105.0000 - true_negatives: 5892.0000 - false_negatives: 82.0000 - auc: 0.7012 - matthews_correlation: 0.1691 - f1: 0.1367 - val_loss: 0.6113 - val_true_positives: 422.0000 - val_false_positives: 4469.0000 - val_true_negatives: 5412.0000 - val_false_negatives: 161.0000 - val_auc: 0.6463 - val_matthews_correlation: 0.0205 - val_f1: 0.0775
# Epoch 42/50
# 109/109 [==============================] - 2s 17ms/step - loss: 0.5712 - true_positives: 384.0000 - false_positives: 4081.0000 - true_negatives: 5916.0000 - false_negatives: 83.0000 - auc: 0.7089 - matthews_correlation: 0.1685 - f1: 0.1353 - val_loss: 0.6150 - val_true_positives: 427.0000 - val_false_positives: 4608.0000 - val_true_negatives: 5273.0000 - val_false_negatives: 156.0000 - val_auc: 0.6391 - val_matthews_correlation: 0.0167 - val_f1: 0.0780
# Epoch 43/50
# 109/109 [==============================] - 2s 20ms/step - loss: 0.5906 - true_positives: 385.0000 - false_positives: 4020.0000 - true_negatives: 5977.0000 - false_negatives: 82.0000 - auc: 0.7066 - matthews_correlation: 0.1739 - f1: 0.1376 - val_loss: 0.6222 - val_true_positives: 439.0000 - val_false_positives: 4600.0000 - val_true_negatives: 5281.0000 - val_false_negatives: 144.0000 - val_auc: 0.6452 - val_matthews_correlation: 0.0342 - val_f1: 0.0831
# Epoch 44/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.5867 - true_positives: 387.0000 - false_positives: 4047.0000 - true_negatives: 5950.0000 - false_negatives: 80.0000 - auc: 0.7017 - matthews_correlation: 0.1685 - f1: 0.1362 - val_loss: 0.6070 - val_true_positives: 434.0000 - val_false_positives: 4530.0000 - val_true_negatives: 5351.0000 - val_false_negatives: 149.0000 - val_auc: 0.6498 - val_matthews_correlation: 0.0342 - val_f1: 0.0833
# Epoch 45/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.5979 - true_positives: 384.0000 - false_positives: 4156.0000 - true_negatives: 5841.0000 - false_negatives: 83.0000 - auc: 0.7018 - matthews_correlation: 0.1627 - f1: 0.1347 - val_loss: 0.6251 - val_true_positives: 457.0000 - val_false_positives: 4919.0000 - val_true_negatives: 4962.0000 - val_false_negatives: 126.0000 - val_auc: 0.6423 - val_matthews_correlation: 0.0392 - val_f1: 0.0865
# Epoch 46/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.5743 - true_positives: 380.0000 - false_positives: 4115.0000 - true_negatives: 5882.0000 - false_negatives: 87.0000 - auc: 0.6949 - matthews_correlation: 0.1630 - f1: 0.1344 - val_loss: 0.6087 - val_true_positives: 416.0000 - val_false_positives: 4070.0000 - val_true_negatives: 5811.0000 - val_false_negatives: 167.0000 - val_auc: 0.6731 - val_matthews_correlation: 0.0400 - val_f1: 0.0780
# Epoch 47/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.5909 - true_positives: 389.0000 - false_positives: 4028.0000 - true_negatives: 5969.0000 - false_negatives: 78.0000 - auc: 0.7267 - matthews_correlation: 0.1731 - f1: 0.1335 - val_loss: 0.6394 - val_true_positives: 443.0000 - val_false_positives: 5001.0000 - val_true_negatives: 4880.0000 - val_false_negatives: 140.0000 - val_auc: 0.6135 - val_matthews_correlation: 0.0119 - val_f1: 0.0806
# Epoch 48/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.5737 - true_positives: 388.0000 - false_positives: 4040.0000 - true_negatives: 5957.0000 - false_negatives: 79.0000 - auc: 0.7128 - matthews_correlation: 0.1733 - f1: 0.1363 - val_loss: 0.6363 - val_true_positives: 434.0000 - val_false_positives: 4753.0000 - val_true_negatives: 5128.0000 - val_false_negatives: 149.0000 - val_auc: 0.6216 - val_matthews_correlation: 0.0184 - val_f1: 0.0807
# Epoch 49/50
# 109/109 [==============================] - 3s 25ms/step - loss: 0.5710 - true_positives: 367.0000 - false_positives: 3911.0000 - true_negatives: 6086.0000 - false_negatives: 100.0000 - auc: 0.6978 - matthews_correlation: 0.1633 - f1: 0.1347 - val_loss: 0.6171 - val_true_positives: 437.0000 - val_false_positives: 4472.0000 - val_true_negatives: 5409.0000 - val_false_negatives: 146.0000 - val_auc: 0.6682 - val_matthews_correlation: 0.0438 - val_f1: 0.0835
# Epoch 50/50
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5910 - true_positives: 394.0000 - false_positives: 3996.0000 - true_negatives: 6001.0000 - false_negatives: 73.0000 - auc: 0.7378 - matthews_correlation: 0.1821 - f1: 0.1343 - val_loss: 0.6690 - val_true_positives: 469.0000 - val_false_positives: 5400.0000 - val_true_negatives: 4481.0000 - val_false_negatives: 114.0000 - val_auc: 0.6062 - val_matthews_correlation: 0.0277 - val_f1: 0.0879
# CPU times: user 3min 27s, sys: 25.8 s, total: 3min 53s
# Wall time: 2min 20s

# %%
# plot learning curves
metric_names =  [
    'loss', 
    'matthews_correlation', 
    'true_positives', 
    'false_positives', 
    'false_negatives', 
    'true_negatives'
]

filename = '../project_info/figures/small_scale_parallel_RNN_learning_curves.png'
print(f"Total observations: {len(training_data)}")

plotting_functions.plot_metrics('Parallel RNN', history, metric_names, filename)
# Out:
# Total observations: 10519

# %%
# %%time
tracemalloc.start()

training_predictions = model.predict(x_training, batch_size=batch_size)
training_ignition_risk_predictions = training_predictions.flatten()
training_true_fires = y_training.flatten()

testing_predictions = model.predict(x_testing, batch_size=batch_size)
testing_ignition_risk_predictions = testing_predictions.flatten()
testing_true_fires = y_testing.flatten()

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f'Peak memory: {np.round((peak / 10**6), 1)} MB')
# Out:
# Peak memory: 35.3 MB
# CPU times: user 3.49 s, sys: 215 ms, total: 3.7 s
# Wall time: 3.37 s

# %%
sns.kdeplot(training_ignition_risk_predictions, cumulative=False, bw=0.01)
plt.xlim(-0.1, 1)
plt.show()

# %%
# %%time
tracemalloc.start()

training_results = model.evaluate(
    x_training,
    y_training,
    batch_size=batch_size
)

testing_results = model.evaluate(
    x_testing,
    y_testing, 
    batch_size=batch_size
)

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f'Peak memory: {np.round((peak / 10**6), 1)} MB')
# Out:
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5975 - true_positives: 404.0000 - false_positives: 4758.0000 - true_negatives: 5239.0000 - false_negatives: 63.0000 - auc: 0.6788 - matthews_correlation: 0.0228 - f1: 0.0745
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6998 - true_positives: 237.0000 - false_positives: 2802.0000 - true_negatives: 2086.0000 - false_negatives: 59.0000 - auc: 0.5876 - matthews_correlation: 0.0350 - f1: 0.0921
# Peak memory: 2.3 MB
# CPU times: user 2.61 s, sys: 362 ms, total: 2.98 s
# Wall time: 2.18 s

# %%
filename ='../project_info/figures/small_scale_parallel_RNN_confusion_matricies.png'  
plotting_functions.plot_cm(training_true_fires, training_ignition_risk_predictions, testing_true_fires, testing_ignition_risk_predictions, filename)
# Out:
# Training data prediction results
# No fire (True Negatives):  5239
# False alarms (False Positives):  4758
# Fires missed (False Negatives):  63
# Fires detected (True Positives):  404
# Total fires:  467
#
# Test data prediction results
# No fire (True Negatives):  2086
# False alarms (False Positives):  2802
# Fires missed (False Negatives):  59
# Fires detected (True Positives):  237
# Total fires:  296

# %%
trimmed_training_dates = training_dates[:training_predictions.shape[0]]

formatted_predictions = pd.DataFrame(columns=['date', 'lat', 'lon', 'prediction'])

for prediction, date in zip(training_predictions, trimmed_training_dates):
    df = pd.DataFrame(list(zip(training_lats, training_lons, prediction)), 
               columns =['lat', 'lon', 'prediction'])
    
    df['date'] = date
    
    formatted_predictions = formatted_predictions.append(df)
    
formatted_predictions.head()
# Out:
#         date        lat         lon  prediction
# 0 1992-01-01  35.232731 -117.260803    0.030539
# 1 1992-01-01  37.182751 -121.959801    0.101915
# 2 1992-01-01  41.552299 -123.944199    0.020917
# 0 1992-01-02  35.232731 -117.260803    0.031441
# 1 1992-01-02  37.182751 -121.959801    0.084971

# %%
formatted_predictions.tail()
# Out:
#         date        lat         lon  prediction
# 1 2001-07-18  37.182751 -121.959801    0.675942
# 2 2001-07-18  41.552299 -123.944199    0.781134
# 0 2001-07-19  35.232731 -117.260803    0.915044
# 1 2001-07-19  37.182751 -121.959801    0.699437
# 2 2001-07-19  41.552299 -123.944199    0.798381

# %%
states_shapefile = '../training_data_pipeline/data/spatial_data/cb_2018_us_state_500k.shp'
california = data_functions.get_california_polygon(states_shapefile)
multipoly = california.loc[16, 'geometry']
california_land_mass = multipoly[-1]

# %%
from descartes import PolygonPatch

left  = 0.125  # the left side of the subplots of the figure
right = 0.65   # the right side of the subplots of the figure
bottom = 0.1   # the bottom of the subplots of the figure
top = 0.9      # the top of the subplots of the figure
wspace = 0.2   # the amount of width reserved for blank space between subplots
hspace = 0.3   # the amount of height reserved for white space between subplots

fig_rows = 8
fig_cols = 2
plot_height = 65
plot_width = 30

plot_locations = [
    (0,0),(0,1),
    (1,0),(1,1),
    (2,0),(2,1),
    (3,0),(3,1),
    (4,0),(4,1),
    (5,0),(5,1),
    (6,0),(6,1),
    (7,0),(7,1)
]

date_list = [
    '1999-01-01',
    '1999-02-01',
    '1999-03-01',
    '1999-04-01',
    '1999-05-01',
    '1999-06-01',
    '1999-07-01',
    '1999-08-01',
    '1999-09-01',
    '1999-10-01',
    '1999-11-01',
    '1999-12-01',
    '2000-01-01',
    '2000-02-01',
    '2000-03-01',
    '2000-04-01'
    
]

# date_list = [
#     '1999-01-01',
#     '1999-01-02',
#     '1999-01-03',
#     '1999-01-04',
#     '1999-01-05',
#     '1999-01-06',
#     '1999-01-07',
#     '1999-01-08',
#     '1999-01-09',
#     '1999-01-10',
#     '1999-01-11',
#     '1999-01-12',
#     '2000-01-13',
#     '2000-01-14',
#     '2000-01-15',
#     '2000-01-16'  
# ]

num_contour_levels = 10

# formatted_predictions['lat'] = formatted_predictions['lat'].astype('float32')
# formatted_predictions['lon'] = formatted_predictions['lon'].astype('float32')

# prediction_data_by_day = formatted_predictions.groupby('date')

fig, ax = plt.subplots(fig_rows, fig_cols, figsize=(plot_width, plot_height))
fig.subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace)

i = 0

while i < 16:
    date = str(date_list[i])
    predictions = formatted_predictions[formatted_predictions['date'] == date]
    predictions.drop('date', axis=1, inplace=True)

    xi, yi, zi = data_functions.regularize_grid(predictions, 'prediction', 0.1)

    ax[plot_locations[i]].add_patch(PolygonPatch(california_land_mass, fc='none', ec='black', lw='2', zorder=2))
    ax[plot_locations[i]].contourf(xi, yi, zi, num_contour_levels, cmap='viridis')
    ax[plot_locations[i]].set_title(date, fontsize=18)
    ax[plot_locations[i]].set_aspect('equal', adjustable='box')
    
    i += 1

# %% [markdown]
# ### Full dataset

# %%
#raw_data.drop(['month'], inplace=True, axis=1)
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3594060 entries, 0 to 3594059
# Data columns (total 14 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   date              datetime64[ns]
#  1   lat               float32
#  2   lon               float32
#  3   apcp              float32
#  4   mean_air_2m       float32
#  5   mean_rhum_2m      float32
#  6   mean_dpt_2m       float32
#  7   mean_pres_sfc     float32
#  8   mean_uwnd_10m     float32
#  9   mean_vwnd_10m     float32
#  10  mean_cloud_cover  float32
#  11  ignition          int32
#  12  raw_lat           float32
#  13  raw_lon           float32
# dtypes: datetime64[ns](1), float32(12), int32(1)
# memory usage: 205.7 MB

# %%
class_0_weight = ()
class_1_weight = ()
bins = raw_data.groupby(['raw_lat', 'raw_lon'])

for name, spatial_bin in bins:
    fires = spatial_bin['ignition'].sum()
    
    if fires == 0:
        class_0_weight = class_0_weight + (1,)
        class_1_weight = class_1_weight + (1,)
    
    else:
        observations = len(spatial_bin)
        class_0_weight = class_0_weight + (((1 / (observations - fires))*(observations)/2.0),)
        class_1_weight = class_1_weight + (((1 / fires)*(observations)/2.0),)

# %%
num_fires = raw_data['ignition'].sum()
total_observations = len(raw_data)
raw_output_bias = np.log([num_fires/(total_observations - num_fires)])[0]
output_bias = tf.keras.initializers.Constant(raw_output_bias)

print(f'Output bias: {raw_output_bias}')
# Out:
# Output bias: -3.3301765288755347

# %%
# make sure data is STILL sorted by date
raw_data['date'] = pd.to_datetime(raw_data['date'])
raw_data = raw_data.set_index('date')
raw_data = raw_data.sort_index()
raw_data.reset_index(inplace=True)

# Split data up into training, testing and validation sets
testing_data = raw_data.tail(int(len(raw_data) * 0.2))
leftover_data = raw_data.head(int(len(raw_data) * 0.8))
validation_data = raw_data.tail(int(len(leftover_data) * 0.5))
training_data = raw_data.head(int(len(leftover_data) * 0.5))

# %%
future_target = 1
step = 1
EPOCHS = 30

# create data sets
x_training, y_training, training_lats, training_lons, training_dates = data_functions.format_features_labels_for_LSTM(
    training_data,        # incomming_data
    past_history,         # size of past history time chunk
    future_target,        # number of future timepoints to predict from each history time chunk
    step,                 # number of timepoints to move the history time chunk as we slide over the data
)

x_validation, y_validation, validation_lats, validation_lons, validation_dates = data_functions.format_features_labels_for_LSTM(
    validation_data,      # incomming_data
    past_history,         # size of past history time chunk
    future_target,        # number of future timepoints to predict from each history time chunk
    step,                 # number of timepoints to move the history time chunk as we slide over the data
)

x_testing, y_testing, testing_lats, testing_lons, testing_dates = data_functions.format_features_labels_for_LSTM(
    testing_data,         # incomming_data
    past_history,         # size of past history time chunk
    future_target,        # number of future timepoints to predict from each history time chunk
    step,                 # number of timepoints to move the history time chunk as we slide over the data
)

x_training, y_training = data_functions.trim_and_reshape_for_LSTM(x_training, y_training)
x_validation, y_validation = data_functions.trim_and_reshape_for_LSTM(x_validation, y_validation)
x_testing, y_testing = data_functions.trim_and_reshape_for_LSTM(x_testing, y_testing)

# trim datasets so they are a whole number factor of the batch size
for i in range(len(x_training)):
    start_index = (x_training[i].shape[0] - (x_training[i].shape[0] % batch_size))
    end_index = x_training[i].shape[0]

    x_training[i] = np.delete(x_training[i], range(start_index, end_index), axis=0)

y_training = np.delete(y_training, range(start_index, end_index), axis=0)

for i in range(len(x_validation)):
    start_index = (x_validation[i].shape[0] - (x_validation[i].shape[0] % batch_size))
    end_index = x_validation[i].shape[0]

    x_validation[i] = np.delete(x_validation[i], range(start_index, end_index), axis=0)

y_validation = np.delete(y_validation, range(start_index, end_index), axis=0)

for i in range(len(x_testing)):
    start_index = (x_testing[i].shape[0] - (x_testing[i].shape[0] % batch_size))
    end_index = x_testing[i].shape[0]

    x_testing[i] = np.delete(x_testing[i], range(start_index, end_index), axis=0)

y_testing = np.delete(y_testing, range(start_index, end_index), axis=0)

print()
print("x_training is {}, length: {}, member shape: {}.".format(type(x_training), len(x_training), x_training[0].shape))
print("y_training is {}, length: {}, member shape: {}.".format(type(y_training), len(y_training), y_training[0].shape))
print()
print("x_validation is {}, length: {}, member shape: {}.".format(type(x_validation), len(x_validation), x_validation[0].shape))
print("y_validation is {}, length: {}, member shape: {}.".format(type(y_validation), len(y_validation), y_validation[0].shape))
print()
print("x_testing is {}, length: {}, member shape: {}.".format(type(x_testing), len(x_testing), x_testing[0].shape))
print("y_testing is {}, length: {}, member shape: {}.".format(type(y_testing), len(y_testing), y_testing[0].shape))
print()

input_dim = x_training[0].shape[-2:]
input_shape = (batch_size, input_dim[0], input_dim[1])
num_bins = len(x_training)
print(f'Input shape: {input_shape}')
print(f'Num bins: {num_bins}')
print()

# steps from batch size
steps_per_epoch = int(len(x_training[0]) // batch_size)
validation_steps = int(len(x_validation[0]) // batch_size)
# Out:
# x_training is <class 'list'>, length: 410, member shape: (3488, 5, 10).
# y_training is <class 'numpy.ndarray'>, length: 3488, member shape: (410,).
#
# x_validation is <class 'list'>, length: 410, member shape: (3488, 5, 10).
# y_validation is <class 'numpy.ndarray'>, length: 3488, member shape: (410,).
#
# x_testing is <class 'list'>, length: 410, member shape: (1728, 5, 10).
# y_testing is <class 'numpy.ndarray'>, length: 1728, member shape: (410,).
#
# Input shape: (32, 5, 10)
# Num bins: 410

# %%
# %%time
tracemalloc.start()

# fc_unit_factor = 0
# fc_layers = 0
# fc_l2_reg = 0

model = make_model(
    num_bins,
    input_shape,
    learning_rate,
    rnn_type,
    statefullness,
    rnn_units,
    rnn_dropout,
    fc_unit_factor,
    fc_layers,
    fc_l2_reg,
    class_0_weight,
    class_1_weight,
    output_bias
)

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f'Peak memory: {np.round((peak / 10**6), 1)} MB')
# Out:
# Peak memory: 426.6 MB
# CPU times: user 2min 52s, sys: 5.63 s, total: 2min 58s
# Wall time: 3min 1s

# %%
# %%time
tracemalloc.start()

history = model.fit(
    x_training,
    y_training,
    epochs=50,
    batch_size=batch_size,
    steps_per_epoch=steps_per_epoch,
    callbacks=[early_stopping_callback],
    validation_data=(x_validation, y_validation),
    validation_steps=validation_steps,
    verbose=1
)

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f'Peak memory: {np.round((peak / 10**6), 1)} MB')
# Out:
# Epoch 1/50
# 109/109 [==============================] - 377s 3s/step - loss: 0.9860 - true_positives: 36138.0000 - false_positives: 473671.0000 - true_negatives: 910697.0000 - false_negatives: 14758.0000 - auc: 0.7383 - matthews_correlation: 0.1408 - f1: 0.0893 - val_loss: 0.9684 - val_true_positives: 35555.0000 - val_false_positives: 542692.0000 - val_true_negatives: 836643.0000 - val_false_negatives: 15190.0000 - val_auc: 0.6982 - val_matthews_correlation: 0.0493 - val_f1: 0.0510
# Epoch 2/50
# 109/109 [==============================] - 121s 1s/step - loss: 0.6318 - true_positives: 39490.0000 - false_positives: 497561.0000 - true_negatives: 881919.0000 - false_negatives: 11110.0000 - auc: 0.7606 - matthews_correlation: 0.1589 - f1: 0.1051 - val_loss: 0.9606 - val_true_positives: 36787.0000 - val_false_positives: 590874.0000 - val_true_negatives: 788461.0000 - val_false_negatives: 13958.0000 - val_auc: 0.6843 - val_matthews_correlation: 0.0401 - val_f1: 0.0528
# Epoch 3/50
# 109/109 [==============================] - 105s 960ms/step - loss: 0.5744 - true_positives: 40438.0000 - false_positives: 495717.0000 - true_negatives: 883763.0000 - false_negatives: 10162.0000 - auc: 0.7705 - matthews_correlation: 0.1663 - f1: 0.1076 - val_loss: 0.9680 - val_true_positives: 36565.0000 - val_false_positives: 561612.0000 - val_true_negatives: 817723.0000 - val_false_negatives: 14180.0000 - val_auc: 0.6941 - val_matthews_correlation: 0.0505 - val_f1: 0.0521
# Epoch 4/50
# 109/109 [==============================] - 121s 1s/step - loss: 0.5617 - true_positives: 40772.0000 - false_positives: 494955.0000 - true_negatives: 884525.0000 - false_negatives: 9828.0000 - auc: 0.7747 - matthews_correlation: 0.1692 - f1: 0.1089 - val_loss: 0.9773 - val_true_positives: 36495.0000 - val_false_positives: 572528.0000 - val_true_negatives: 806807.0000 - val_false_negatives: 14250.0000 - val_auc: 0.6851 - val_matthews_correlation: 0.0462 - val_f1: 0.0524
# Epoch 5/50
# 109/109 [==============================] - 142s 1s/step - loss: 0.5451 - true_positives: 40971.0000 - false_positives: 485080.0000 - true_negatives: 894400.0000 - false_negatives: 9629.0000 - auc: 0.7820 - matthews_correlation: 0.1740 - f1: 0.1103 - val_loss: 0.9733 - val_true_positives: 37419.0000 - val_false_positives: 558470.0000 - val_true_negatives: 820865.0000 - val_false_negatives: 13326.0000 - val_auc: 0.7066 - val_matthews_correlation: 0.0602 - val_f1: 0.0537
# Epoch 6/50
# 109/109 [==============================] - 132s 1s/step - loss: 0.5347 - true_positives: 41387.0000 - false_positives: 479966.0000 - true_negatives: 899514.0000 - false_negatives: 9213.0000 - auc: 0.7893 - matthews_correlation: 0.1786 - f1: 0.1110 - val_loss: 0.9819 - val_true_positives: 37470.0000 - val_false_positives: 546619.0000 - val_true_negatives: 832716.0000 - val_false_negatives: 13275.0000 - val_auc: 0.7154 - val_matthews_correlation: 0.0647 - val_f1: 0.0543
# Epoch 7/50
# 109/109 [==============================] - 132s 1s/step - loss: 0.5209 - true_positives: 41652.0000 - false_positives: 469931.0000 - true_negatives: 909549.0000 - false_negatives: 8948.0000 - auc: 0.7960 - matthews_correlation: 0.1849 - f1: 0.1124 - val_loss: 0.9995 - val_true_positives: 37224.0000 - val_false_positives: 540892.0000 - val_true_negatives: 838443.0000 - val_false_negatives: 13521.0000 - val_auc: 0.7117 - val_matthews_correlation: 0.0667 - val_f1: 0.0541
# Peak memory: 2297.9 MB
# CPU times: user 40min 1s, sys: 4min 2s, total: 44min 3s
# Wall time: 31min 31s

# %%
# plot learning curves
metric_names =  [
    'loss', 
    'matthews_correlation', 
    'true_positives', 
    'false_positives', 
    'false_negatives', 
    'true_negatives'
]

filename = '../project_info/figures/small_parallel_RNN_learning_curves.png'
print(f"Total observations: {len(training_data)}")

plotting_functions.plot_metrics('Parallel RNN', history, metric_names, filename)
# Out:
# Total observations: 1437624

# %%
# %%time
tracemalloc.start()

training_predictions = model.predict(x_training, batch_size=batch_size)
training_ignition_risk_predictions = training_predictions.flatten()
training_true_fires = y_training.flatten()

testing_predictions = model.predict(x_testing, batch_size=batch_size)
testing_ignition_risk_predictions = testing_predictions.flatten()
testing_true_fires = y_testing.flatten()

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f'Peak memory: {np.round((peak / 10**6), 1)} MB')
# Out:
# Peak memory: 542.9 MB
# CPU times: user 3min 25s, sys: 11.2 s, total: 3min 36s
# Wall time: 3min 7s

# %%
filename ='../project_info/figures/parallel_RNN_confusion_matricies.png'  
plotting_functions.plot_cm(training_true_fires, training_ignition_risk_predictions, testing_true_fires, testing_ignition_risk_predictions, filename)
# Out:
# Training data prediction results
# No fire (True Negatives):  772175
# False alarms (False Positives):  603169
# Fires missed (False Negatives):  5658
# Fires detected (True Positives):  44568
# Total fires:  50226
#
# Test data prediction results
# No fire (True Negatives):  320576
# False alarms (False Positives):  354045
# Fires missed (False Negatives):  5467
# Fires detected (True Positives):  21012
# Total fires:  26479

# %%
trimmed_training_dates = training_dates[:training_predictions.shape[0]]

formatted_predictions = pd.DataFrame(columns=['date', 'lat', 'lon', 'prediction'])

for prediction, date in zip(training_predictions, trimmed_training_dates):
    df = pd.DataFrame(list(zip(training_lats, training_lons, prediction)), 
               columns =['lat', 'lon', 'prediction'])
    
    df['date'] = date
    
    formatted_predictions = formatted_predictions.append(df)
    
formatted_predictions.head()
# Out:
#         date        lat         lon  prediction
# 0 1992-01-01  32.683891 -117.180901    0.069493
# 1 1992-01-01  32.721279 -116.851196    0.162713
# 2 1992-01-01  32.757439 -116.521004    0.224700
# 3 1992-01-01  32.792389 -116.190498    0.151542
# 4 1992-01-01  32.826099 -115.859596    0.582403

# %%
states_shapefile = '../training_data_pipeline/data/spatial_data/cb_2018_us_state_500k.shp'
california = data_functions.get_california_polygon(states_shapefile)
multipoly = california.loc[16, 'geometry']
california_land_mass = multipoly[-1]

# %%
from descartes import PolygonPatch

left  = 0.125  # the left side of the subplots of the figure
right = 0.65   # the right side of the subplots of the figure
bottom = 0.1   # the bottom of the subplots of the figure
top = 0.9      # the top of the subplots of the figure
wspace = 0.2   # the amount of width reserved for blank space between subplots
hspace = 0.3   # the amount of height reserved for white space between subplots

fig_rows = 8
fig_cols = 2
plot_height = 65
plot_width = 30

plot_locations = [
    (0,0),(0,1),
    (1,0),(1,1),
    (2,0),(2,1),
    (3,0),(3,1),
    (4,0),(4,1),
    (5,0),(5,1),
    (6,0),(6,1),
    (7,0),(7,1)
]

# date_list = [
#     '1999-01-01',
#     '1999-02-01',
#     '1999-03-01',
#     '1999-04-01',
#     '1999-05-01',
#     '1999-06-01',
#     '1999-07-01',
#     '1999-08-01',
#     '1999-09-01',
#     '1999-10-01',
#     '1999-11-01',
#     '1999-12-01',
#     '2000-01-01',
#     '2000-02-01',
#     '2000-03-01',
#     '2000-04-01'
    
# ]

date_list = [
    '1999-01-01',
    '1999-01-02',
    '1999-01-03',
    '1999-01-04',
    '1999-01-05',
    '1999-01-06',
    '1999-01-07',
    '1999-01-08',
    '1999-01-09',
    '1999-01-10',
    '1999-01-11',
    '1999-01-12',
    '2000-01-13',
    '2000-01-14',
    '2000-01-15',
    '2000-01-16'  
]

num_contour_levels = 100

# formatted_predictions['lat'] = formatted_predictions['lat'].astype('float32')
# formatted_predictions['lon'] = formatted_predictions['lon'].astype('float32')
# prediction_data_by_day = formatted_predictions.groupby('date')

fig, ax = plt.subplots(fig_rows, fig_cols, figsize=(plot_width, plot_height))
fig.subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace)

i = 0

while i < 16:
    date = str(date_list[i])
    predictions = formatted_predictions[formatted_predictions['date'] == date]
    predictions.drop('date', axis=1, inplace=True)

    xi, yi, zi = data_functions.regularize_grid(predictions, 'prediction', 0.01)

    ax[plot_locations[i]].add_patch(PolygonPatch(california_land_mass, fc='none', ec='black', lw='2', zorder=2))
    ax[plot_locations[i]].contourf(xi, yi, zi, num_contour_levels, cmap='viridis')
    ax[plot_locations[i]].set_title(date, fontsize=18)
    ax[plot_locations[i]].set_aspect('equal', adjustable='box')
    
    i += 1

# %%
# %%time

# save model note: need to use .h5 format to avoid apparent memory leak in TF 
# bug report: https://github.com/tensorflow/tensorflow/issues/32234
tracemalloc.start()

model.save('./trained_models/parallel_RNN.3.h5')

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(f'Peak memory: {np.round((peak / 10**6), 1)} MB')
# Out:
# Peak memory: 63.5 MB
# CPU times: user 6.27 s, sys: 342 ms, total: 6.62 s
# Wall time: 6.22 s
